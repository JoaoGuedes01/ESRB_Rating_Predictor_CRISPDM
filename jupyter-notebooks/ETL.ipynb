# %% [markdown]
# ### Cenário
# Resumindo o relatado na fase de Business Understanding, a nossa equipa foi contratada pela Sony para desenvolver um algoritmo de previsão do ESRB rating, isto, de modo que a Sony na fase de desenvolvimento dos seus jogos, consigam desenvolver as funcionalidades e campanhas de marketing corretas de acordo com o ESRB pretendido. Assim, o nosso algoritmo fará reduzir os custos de produção do jogo, nomeadamente no que toca ao custo das funcionalidades e marketing, pois a empresa necessitará de reformular o jogo menos vezes, não sendo construídas acidentalmente funcionalidades erradas (ou seja, fora do âmbito do ESRB rating pretendido), e as campanhas de marketing poderão ser muito mais focadas para um público específico desde o início. Estes dois ganhos em eficiência refletem-se no aumento dos lucros da empresa.
#
# ### Pressupostos
# - **Todos os jogos incluem a PS4:** Uma vez que o cliente é a Sony, a desenvolvedora da PS4, há possibilidade de haver análises de jogos exclusivos (apenas PS4) assim como multiplataforma (PS4 e Xbox One). Assim torna-se imprescindível a adição de um filtro para a consola nas dashboards.
#
# - **Datas de lançamento e custos de produção dos jogos:** A Sony para a fase de Deployment, forneceu à equipa dois novos datasets com as datas de lançamento e os custos de produção dos jogos que complementam o dataset original (train.csv).
#
# - **Classificação ESRB final:** Os jogos são classificados pela organização ESRB e a classificação final apenas de aplica depois do jogo estar finalizado. Caso o jogo obtenha uma classificação não pretendida pela Sony, esta reformula o jogo, alterando e/ou eliminando funcionalidades e campanhas de marketing já planeadas. A reformulação do jogo implica custos de produção adicionais, esses que já estão pressupostos no novo dataset com os custos de produção. Assim este pressuposto complementa a nossa justificação para a redução dos custos de produção, uma vez que ao utilizar o nosso algoritmo, o jogo obterá a classificação pretendida a maior parte das vezes.
#
# ### Objetivo de Data Mining
# Exatidão na previsão do ESRB Rating de um jogo
#
# ### Objetivo de Negócio
# Aumentar os lucros na venda dos jogos
#
# ### Fator Crítico de Sucesso
# Diminuir os custos na fase de produção de um jogo
#
# ### KPIs
# Todos os nossos KPIs são medidos em função da dimensão tempo (dim_date) do nosso Data Warehouse. A equipa identificou os seguintes KPIs:
# - **Novos gastos no desenvolvimento do jogo:** Estes gastos estão relacionados com atividades do desenvolvimento e criação do jogo, desde assets a peças musicais, o jogo existe graças a estes gastos.
# - **Novos gastos nas campanhas de marketing:**  Estes gastos são relacionados com as atividades de marketing do jogo, campanhas, anúncios, marketing digital, entre outros. Muitas vezes estas atividades começam "cedo" no ciclo de vida do jogo o que leva a falhas no âmbito do jogo e terem de ser refeitas aquando da averiguação do ESRB Rating que o jogo acabou por ter depois de estar terminado.
# - **Taxa de acerto:** A taxa de acertos reflete-se na quantidade de previsões corretas do nosso modelo face ao total de amostras.
# - **Taxa de erro:** A taxa de acertos reflete-se na quantidade de previsões erradas do nosso modelo face ao total de amostras.
#
# ### Projeto 1
# Ao realizar o projeto 1, concluimos e as **redes neuronais MLP Classifier é o melhor modelo**. Apresentando uma **exatidão de 87,54%** e um **tempo de treino de aproximadamente 16.56 segundos** para o treino de 4/5 do dataset **do cenário 2 de testes**.
# <br>O cenário 2 apenas remove 4 features do dataset original (mild_language, mature_humor, console e use_of_drugs_and_alcohol), estes foram os atributos com um score menor que 10 na nossa análise de seleção univariada de atributos com o algoritmo chi2.
# <br>Ainda, de modo a fiabilizar a nossa exatidão, **foi aplicada a cross validations, com 5 Stratified K-Folds**, isto é, todos os Folds possuiem a mesma quantidade da variável target, no nosso caso, do esrb_rating.
# <br>De modo a melhorar os resultados, **fizemos a hisperparameterização** e antes de ser feito o treino dos dados, **aplicamos o SMOTE** aos mesmos, isto é, uma **técnica de oversampling** para balancear a quantidade de dados.
# <br>![Cenário 2 de Testes](images/NB_results_scenery2.png)
#
# ### Projeto 2
# Para a previsão do ESRB rating de cada jogo a carregar no Data Warehouse foi utilizado o algoritmo com melhor exatidão identificado pela equipa na fase de Evaluation, o MLP Classifier.
# <br>Uma vez que nos foi entregue um dataset com as datas de lançamento dos jogos, **o nosso cliente (Sony) pediu para prever todos os jogos com data de lançamento igual ou superior a 2019, sendo os restantes para treino do modelo**. A partir do SweetViz conseguimos afirmar que os novos dados de treino e teste representam, ordenadamente, 62% e 38% do dataset (train.csv). Devido a isto, o valor de exatidão alterou de 87,54% para 85.19%, porém permanece no mesmo nível que o anterior (exatidão entre 85%-89%).

# %% [markdown]
# ## Table Of Contents <a name = "index"></a>
# - [1. Generate Datasets (Extract)](#genDatasets)
#   - [A. Generate Release Dates](#genReleaseDates)
#   - [B. Generate Costs](#genCosts)
# - [2. Data Warehousing (Transformation and Loading)](#dw)
#   - [A. Generate Database](#genDB)
#   - [B. Generate Tables](#genTables)
#   - [C. Populate Dimensions](#popDims)
#     - [i. dim_esrb_rating_scale](#dim_esrb_rating_scale)
#     - [ii. dim_console](#dim_console)
#     - [ii. dim_console](#dim_console)
#     - [iii. dim_date](#dim_date)
#   - [D. Populate Fact Table](#popFact)
#     - [i. fact_game](#fact_game)
#   - [E. Create Views](#createViews)
#     - [i. view_game_prediction](#view_game_prediction)

# %%
import pandas as pd
import numpy as np
import http.client
import requests
import json
from datetime import datetime
import sweetviz as sv

import mysql.connector
import joblib

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 1. Generate Datasets (Extract) <a name = "genDatasets"></a>

# %% [markdown]
# ## A. Generate Release Dates <a name = "genReleaseDates"></a>
# - **Datas de Lançamento dos Jogos:** Utilizamos 2 APIs diferentes para a reunião das datas de lançamento de todos os jogos presentes no nosso dataset. Porém na implementação, quer de uma quer de outra, existiram sempre outliers como jogos não presentes na API, ou datas de lançamento erradas ou em falta. Por este mesmo motivo decidimos juntar as 2 APIs ao invés de utilizar apenas 1 e diminuir drasticamente o número de outliers. Para além que, jogos não identificados por ambas as APIs, foram adicionados à medida no ínicio do script.
#
# [Voltar ao Índice](#index)

# %%
games = pd.read_csv('data/train.csv')

# Neste momento estamos a ir buscar datas para 140 jogos diferentes a esta API
def getReleaseDateRAWG(gameTitle):
    res = requests.get(f"https://api.rawg.io/api/games?key=dc7364f0802a4a7bbcc2274673135d53&search={gameTitle}")
    date = res.json()['results'][0]['released']
    date = datetime.strptime(f'{date}', '%Y-%m-%d')
    return date

def insertValues(date):
    arrDates.append(date.date())
    arrYears.append(date.year)
    arrMonths.append(date.month)
    arrDays.append(date.day)


conn = http.client.HTTPSConnection("api.igdb.com")
headers = {
    'Client-ID': "d7an1titccgkj3owhu40nr9a2up0se",
    'Authorization': "Bearer jnwoidpq8nb4vmilfnop70pn0x10t6",
    'Content-Type': "text/plain"
}

arrTitles = []
arrConsoles = []
arrDates = []
arrYears = []
arrMonths = []
arrDays = []

for i in range(len(games)):
    row = games.loc[i,:]
    gameTitle = row['title']
    arrTitles.append(gameTitle)
    arrConsoles.append(row['console'])
    
    # Jogos não enocontrados em nenhum das duas APIs, então inserimos as suas release dates à medida
    if (gameTitle == "TRANSFORMERS:BATTLEGROUNDS"):
        date = datetime.strptime('2020-10-23', '%Y-%m-%d')
        insertValues(date)
        continue
    if (gameTitle == "Home Run Derby VR"):
        date = datetime.strptime('2018-04-26', '%Y-%m-%d')
        insertValues(date)
        continue
    if (gameTitle == "Dungeon of the Endless"):
        date = datetime.strptime('2018-04-26', '%Y-%m-%d')
        insertValues(date)
        continue
    if (gameTitle == "Another Sight"):
        date = datetime.strptime('2019-06-18', '%Y-%m-%d')
        insertValues(date)
        continue
    if (gameTitle == "Dusk Diver"):
        date = datetime.strptime('2019-10-29', '%Y-%m-%d')
        insertValues(date)
        continue
    if (gameTitle == "UPPERS"):
        date = datetime.strptime('2020-10-21', '%Y-%m-%d')
        insertValues(date)
        continue
    if (gameTitle == "One Piece: Grand Cruise"):
        date = datetime.strptime('2018-05-21', '%Y-%m-%d')
        insertValues(date)
        continue
    #
        
    payload = "fields name, release_dates.date, release_dates.platform.name, release_dates.human;\nlimit 100;\nsearch \"{}\";".format(gameTitle).encode('utf-8')
    conn.request("POST", "/v4/games", payload, headers)
    res = conn.getresponse()
    data = res.read()
    jsonObj = json.loads(data.decode("utf-8"))
    if not len(jsonObj) > 0:
        # Sem resposta da API igdb
        date = getReleaseDateRAWG(gameTitle)
        insertValues(date)

    else:
        try:
            if 'release_dates' not in jsonObj[0]:
                # Nao tem realease date na API igdb
                date = getReleaseDateRAWG(gameTitle)
                insertValues(date)
            else:
                ps = 0
                xbox = 0
                psDate = []
                xboxDate = []
                date = ""
                for i2 in jsonObj[0]['release_dates']:
                    if i2['platform']['name']=='PlayStation 3' or i2['platform']['name']=='PlayStation 4':
                        ps = 1
                        timestamp = i2['date']
                        psDate.append(timestamp)
                    elif i2['platform']['name']=='Xbox 360' or i2['platform']['name']=='Xbox One':
                        xbox = 1
                        timestamp = i2['date']
                        xboxDate.append(timestamp)
                     
                if len(psDate) > 0:
                    psDate = max(psDate)
                    psDate = datetime.fromtimestamp(timestamp)
                if len(xboxDate) > 0:
                    xboxDate = max(xboxDate)
                    xboxDate = datetime.fromtimestamp(timestamp)

                if ps == 1 and xbox == 1:
                    if psDate >= xboxDate:
                        date = psDate
                    else:
                        date = xbobxDate
                elif ps == 1 and xbox == 0:
                    date = psDate
                elif ps == 0 and xbox == 1:
                    date = xboxDate
                elif ps == 0 and xbox == 0:
                    date = getReleaseDateRAWG(gameTitle)

                insertValues(date)
        except:
            # Data invalida da API igdb
            date = getReleaseDateRAWG(gameTitle)
            insertValues(date)
    print(f"{i} - {gameTitle} - Release Date: {date.date()}")
# Out:
# 0 - >Observer_ - Release Date: 2017-08-15
# 1 - THE KING OF FIGHTERS '97 GLOBAL MATCH - Release Date: 2018-04-03
# 2 - Far Cry New Dawn - Release Date: 2019-02-15
# 3 - Candle: The Power of the Flame - Release Date: 2018-07-25
# 4 - Planet of the Eyes - Release Date: 2017-09-19
# 6 - Saints Row: The Third Remastered - Release Date: 2020-05-22
# 7 - ACA NEOGEO WAKU WAKU 7 - Release Date: 2018-03-22
# 8 - Battle Chef Brigade Deluxe - Release Date: 2017-11-19
# 9 - The Ninja Saviors: Return of the Warriors - Release Date: 2019-10-15
# 10 - Airheart - Tales of broken Wings - Release Date: 2018-07-24
# 11 - Battlestar Galactica Deadlock - Release Date: 2017-12-08
# 12 - Northgard - Release Date: 2019-09-26
# 13 - Football Nation VR 2018 - Release Date: 2017-11-10
# 14 - Dragon Star Varnir - Release Date: 2019-06-11
# 15 - At Sundown - Release Date: 2019-01-22
# 16 - The Sims™ 4 Tiny Living - Release Date: 2020-02-04
# 17 - Batman: The Enemy Within - Episode 3: Fractured Mask - Release Date: 2017-11-21
# 18 - Paranoia: Happiness is Mandatory - Release Date: 2019-10-03
# 19 - Azure Reflections - Release Date: 2018-05-15
# 20 - Tour de France Season 2019 - Release Date: 2015-06-18
# 21 - The Persistence - Release Date: 2020-05-21
# 22 - Cat Quest II - Release Date: 2019-10-24
# 23 - The Princess Guide - Release Date: 2019-03-26
# 24 - Penn & Teller VR: Frankly Unfair, Unkind, Unnecessary, & Underhanded - Release Date: 2019-07-09
# 25 - Tropico 6  - Release Date: 2019-09-27
# 26 - Nelke & the Legendary Alchemists: Ateliers of the New World - Release Date: 2019-01-31
# 27 - Riddled Corpses EX - Release Date: 2018-06-06
# 28 - Transference  - Release Date: 2018-09-18
# 29 - RICO - Release Date: 2021-10-21
# 30 - That's You! - Release Date: 2017-06-29
# 31 - THE SHAPESHIFTING DETECTIVE - Release Date: 2018-11-06
# 32 - Omen of Sorrow - Release Date: 2021-09-15
# 33 - Inksplosion - Release Date: 2018-05-11
# 34 - NBA Live 19 The One Edition - Release Date: 2018-09-07
# 35 - Track Lab - Release Date: 2018-08-21
# 36 - HUE - Release Date: 2016-08-30
# 37 - Trover Saves the Universe - Release Date: 2019-05-31
# 38 - Songbringer - Release Date: 2017-09-05
# 39 - America's Greatest Game Shows: Wheel of Fortune & Jeopardy!  - Release Date: 2017-11-07
# 40 - Nickelodeon Kart Racers - Release Date: 2018-10-26
# 41 - TO THE TOP - Release Date: 2017-05-18
# 42 - 1001 Spikes - Release Date: 2015-11-27
# 43 - Enter the Gungeon  - Release Date: 2017-04-05
# 44 - Fall Guys - Release Date: 2020-08-04
# 45 - Cobra Kai: The Karate Kid Saga Continues - Release Date: 2020-10-27
# 46 - Overcooked! 2 - Release Date: 2019-10-17
# 47 - Fire Pro Wrestling World - Release Date: 2018-09-28
# 48 - Poop Slinger - Release Date: 2018-08-06
# 49 - Personality and Psychology Premium - Release Date: 2018-06-08
# 50 - MechaNika - Release Date: 2019-11-07
# 51 - Professional Farmer: American Dream - Release Date: 2020-05-06
# 52 - Hello Neighbor: Hide and Seek - Release Date: 2018-12-07
# 53 - ACA NEOGEO NINJA COMMANDO - Release Date: 2018-09-06
# 54 - Shadow of the Tomb Raider - Release Date: 2018-09-14
# 55 - YU-NO: A girl who chants love at the bound of this world. - Release Date: 2019-10-04
# 56 - Surviving the Aftermath - Release Date: 2021-11-16
# 57 - Energy Invasion - Release Date: 2018-01-10
# 58 - Ion Fury - Release Date: 2020-05-14
# 59 - The Walking Dead: A New Frontier - Release Date: 2016-12-20
# 60 - TOKYO CHRONOS - Release Date: 2019-08-26
# 61 - Warhammer 40,000: Inquisitor - Martyr - Release Date: 2018-08-23
# 62 - WWE 2K18 Cena (Nuff) Edition - Release Date: 2017-10-17
# 63 - 2MD VR Football - Release Date: 2018-05-08
# 64 - Yakuza: Kiwami 2 - Release Date: 2020-07-29
# 65 - XIII - Release Date: 2012-09-28
# 66 - Asemblance: Oversight - Release Date: 2018-08-03
# 67 - The Golf Club 2019 Featuring the PGA Tour - Release Date: 2018-08-28
# 68 - INDIGO PROPHECY - Release Date: 2016-08-10
# 69 - Black Clover: Quartet Knights - Release Date: 2018-09-14
# 70 - Mutant Football League - Release Date: 2019-04-18
# 71 - Arcade Archives HAUNTED CASTLE - Release Date: 2016-12-01
# 72 - Persona 4: Dancing All Night - Release Date: 2018-12-04
# 73 - ACA NEOGEO CROSSED SWORDS - Release Date: 2018-08-23
# 74 - World of Warships Legends  - Release Date: 2019-08-12
# 75 - DOG GONE GOLFING - Release Date: 2018-08-14
# 76 - Azur Lane: Crosswave - Release Date: 2020-02-21
# 77 - Assassin's Creed Valhalla - Release Date: 2020-11-10
# 78 - Defiance 2050 - Release Date: 2018-07-10
# 79 - Cooking Mama: Cookstar - Release Date: 2020-04-28
# 80 - The Sims™ 4 Realm of Magic - Release Date: 2019-10-15
# 81 - The Binding of Isaac: Afterbirth+ - Release Date: 2017-06-30
# 82 - BLACKHOLE: Complete Edition - Release Date: 2017-08-08
# 83 - GALAK-Z - Release Date: 2017-02-23
# 84 - Maria The Witch - Release Date: 2018-10-09
# 85 - Lunar Stone: Origin of Blood - Release Date: 2016-11-18
# 86 - WWE 2K Battlegrounds - Release Date: 2020-09-18
# 87 - For Honor: Marching Fire Edition - Release Date: 2018-12-31
# 88 - NBA 2K19 - Release Date: 2018-09-11
# 89 - Worse Than Death - Release Date: 2019-10-08
# 90 - SPARC - Release Date: 2017-08-29
# 91 - Children of Zodiarcs - Release Date: 2020-03-27
# 92 - Hitman: Game of the Year Edition - Release Date: 2017-11-07
# 93 - GUNGRAVE VR U.N - Release Date: 2018-12-11
# 94 - Xenon Valkyrie+ - Release Date: 2018-02-20
# 95 - DiRT Rally 2.0 - Release Date: 2019-02-26
# 96 - Voltron VR Chronicles - Release Date: 2017-09-26
# 97 - InnerSpace - Release Date: 2018-01-16
# 98 - World of Tanks - Release Date: 2010-08-12
# 99 - theHunter: Call of the Wild - 2019 Edition - Release Date: 2018-10-16
# 100 - Brigandine: The Legend of Runersia - Release Date: 2020-12-10
# 101 - R.B.I. Baseball 2018 - Release Date: 1988-01-01
# 102 - Operation Warcade - Release Date: 2018-03-15
# 103 - ACA NEOGEO BURNING FIGHT - Release Date: 2017-09-28
# 104 - MX vs ATV All Out - Release Date: 2018-03-27
# 105 - 911 Operator - Release Date: 2017-11-28
# 106 - Super Comboman: Smash Edition - Release Date: 2017-08-22
# 107 - DISSIDIA FINAL FANTASY NT - Release Date: 2019-03-12
# 108 - Bravo Team - Release Date: 2018-03-07
# 109 - Pathfinder: Kingmaker - Definitive Edition  - Release Date: 2020-08-18
# 110 - Don't Knock Twice - Release Date: 2017-09-05
# 111 - Monster Boy and the Cursed Kingdom - Release Date: 2018-12-04
# 112 - One More Dungeon - Release Date: 2018-08-01
# 113 - The Bridge - Release Date: 2013-02-22
# 114 - Home - Release Date: 2012-08-31
# 115 - River City Melee: Battle Royal Special - Release Date: 2017-04-28
# 116 - DIRT 5 - Release Date: 2020-11-06
# 117 - PLAYERUNKNOWN'S BATTLEGROUNDS - Release Date: 2020-10-29
# 118 - DARK ECLIPSE - Release Date: 2018-09-25
# 120 - Hell Warders - Release Date: 2018-11-29
# 121 - Wandersong - Release Date: 2019-12-06
# 122 - Paper Beast - Release Date: 2020-03-24
# 123 - Iris.Fall - Release Date: 2021-01-07
# 124 - EA SPORTS™ MADDEN NFL 21 ÉDITION NXT LVL - Release Date: 2020-08-25
# 125 - Ultimate Chicken Horse - Release Date: 2017-12-15
# 126 - Immortal Redneck - Release Date: 2018-02-27
# 127 - Farming Simulator 19 - Release Date: 2020-12-28
# 128 - ASSAULT GUNNERS HD EDITION - Release Date: 2018-03-20
# 129 - Whispering Willows - Release Date: 2015-08-28
# 130 - Bloodstained: Curse of the Moon - Release Date: 2018-06-06
# 131 - LA-MULANA 1 & 2 - Release Date: 2012-07-12
# 132 - Truck Racing Championship - Release Date: 2019-07-18
# 133 - Skyworld - Release Date: 2019-03-26
# 134 - Zero Escape: Zero Time Dilemma - Release Date: 2017-12-31
# 135 - Kentucky Route Zero: TV Edition - Release Date: 2020-01-28
# 136 - SIMULACRA - Release Date: 2019-12-03
# 137 - Beholder 2 - Release Date: 2020-04-09
# 138 - Lichtspeer: Double Speer Edition - Release Date: 2018-06-01
# 139 - Legendary Eleven - Release Date: 2021-06-30
# 140 - Jamestown+ - Release Date: 2015-03-18
# 141 - World of Warships Legends: Firepower Deluxe Edition - Release Date: 2019-04-16
# 142 - Frane: Dragons' Odyssey - Release Date: 2019-04-05
# 143 - Game Tengoku CruisinMix - Release Date: 2017-11-30
# 144 - Fist of the North Star: Lost Paradise - Release Date: 2018-10-02
# 145 - de Blob - Release Date: 2018-02-27
# 146 - Night Trap - 25th Anniversary Edition - Release Date: 2017-08-15
# 147 - Damascus Gear: Operation Tokyo - Release Date: 2013-12-25
# 148 - Hunt: Showdown - Release Date: 2019-09-20
# 149 - Spiral Splatter - Release Date: 2018-03-13
# 150 - Risk of Rain - Release Date: 2019-08-30
# 151 - Rym 9000 - Release Date: 2019-02-19
# 152 - Virry VR: Wild Encounters - Release Date: 2018-04-24
# 153 - Our World is Ended - Release Date: 2019-05-02
# 154 - Mercenaries Wings: The False Phoenix - Release Date: 2018-10-10
# 155 - The Sojourn - Release Date: 2019-09-20
# 156 - Greedfall - Release Date: 2019-09-10
# 157 - The Bard's Tale IV: Director's Cut - Release Date: 2019-08-27
# 158 - RiftStar Raiders - Release Date: 2018-02-28
# 159 - Monster Energy Supercross - The Official Videogame 2 - Release Date: 2019-02-08
# 160 - Fast & Furious: Crossroads - Release Date: 2020-08-05
# 161 - Tom Clancy's The Division 2  - Release Date: 2019-03-15
# 162 - Crossing Souls - Release Date: 2018-02-13
# 163 - Run Dorothy Run - Release Date: 2018-02-20
# 164 - Insane Robots - Release Date: 2018-07-10
# 165 - Afterparty - Release Date: 2019-10-29
# 166 - Marble Duel - Release Date: 2021-01-20
# 167 - Slayaway Camp: Butcher´s cut - Release Date: 2017-11-01
# 168 - Stranger Things 3: The Game - Release Date: 2019-07-04
# 169 - Les Sims™ 4 Escapade enneigée  - Release Date: 2014-09-02
# 170 - ACA NEOGEO SHOCK TROOPERS - Release Date: 2018-01-25
# 171 - SWORD ART ONLINE: FATAL BULLET - Release Date: 2018-02-18
# 172 - Art of Fighting Anthology  - Release Date: 2017-08-30
# 173 - Super Street: The Game - Release Date: 2018-09-11
# 174 - Kabounce - Release Date: 2018-05-29
# 175 - Runestone Keeper - Release Date: 2018-04-25
# 176 - FAIRY TAIL - Release Date: 2020-07-30
# 177 - Suicide Guy - Release Date: 2018-02-22
# 178 - Digimon Story: Cyber Sleuth - Hacker's Memory - Release Date: 2018-03-31
# 179 - Pixel Ripped 1989 - Release Date: 2018-07-31
# 180 - R.B.I. Baseball '20 - Release Date: 2020-03-17
# 181 - Overpass - Release Date: 2020-03-17
# 182 - 1971 Project Helios - Release Date: 2020-06-09
# 183 - THE KING OF FIGHTERS 2000 - Release Date: 2016-05-03
# 184 - ACA NEOGEO STREET HOOP - Release Date: 2017-11-09
# 185 - The Shapeshifting Detective - Release Date: 2018-11-06
# 186 - The Council - Episode 1 - The Mad Ones - Release Date: 2018-03-13
# 187 - BUTCHER - Release Date: 2017-05-10
# 188 - Madden NFL 19 - Release Date: 2018-08-10
# 189 - Cyberpunk 2077 - Release Date: 2020-12-10
# 190 - Everybody's Golf VR - Release Date: 2019-05-21
# 191 - Mortal Shell - Release Date: 2020-08-18
# 192 - Happy Drummer - Release Date: 2017-12-21
# 193 - Domino Craft VR - Release Date: 2016-12-21
# 194 - Streets of Rage 4 - Release Date: 2020-06-25
# 195 - Runbow - Release Date: 2018-07-03
# 196 - Minecraft - Release Date: 2009-05-10
# 197 - Red Faction Guerrilla Re-Mars-tered - Release Date: 2018-07-03
# 198 - Tooth and Tail - Release Date: 2017-09-12
# 199 - Streets of Rogue - Release Date: 2019-07-12
# 200 - MINIT - Release Date: 2018-04-03
# 201 - Friday the 13th: The Game  - Release Date: 2017-05-26
# 202 - I Hate Running Backwards - Release Date: 2018-05-22
# 203 - Grab the Bottle - Release Date: 2016-12-19
# 204 - Hero Must Die. again - Release Date: 2020-02-26
# 205 - Phantom Doctrine - Release Date: 2018-08-14
# 206 - Devil May Cry 5 - Release Date: 2019-03-08
# 207 - Forager - Release Date: 2019-07-31
# 208 - Antiquia Lost - Release Date: 2019-06-19
# 209 - LA-MULANA 1 & 2 Hidden Treasures Edition - Release Date: 2012-07-12
# 210 - MudRunner: A Spintires Game - Release Date: 2017-10-31
# 211 - Lapis x Labyrinth - Release Date: 2019-05-28
# 212 - BALAN WONDERWORLD - Release Date: 2021-03-26
# 213 - Dragon's Crown Pro - Release Date: 2018-05-15
# 214 - ACA NEOGEO POWER SPIKES II - Release Date: 2018-01-18
# 215 - Werewolf: The Apocalypse - Earthblood - Release Date: 2021-02-04
# 216 - Destiny 2: Beyond Light - Release Date: 2020-11-10
# 217 - Heroland - Release Date: 2020-01-31
# 218 - EVERSPACE™ Galactic Edition - Release Date: 2018-05-29
# 219 - Morphite - Release Date: 2017-09-20
# 220 - MY UNIVERSE - FASHION BOUTIQUE - Release Date: 2020-10-27
# 221 - SINNER: Sacrifice for Redemption - Release Date: 2018-10-18
# 222 - Road Redemption - Release Date: 2018-12-19
# 223 - Premium Pool Arena - Release Date: 2018-02-20
# 224 - Race Arcade - Release Date: 2017-08-04
# 225 - Danganronpa V3: Killing Harmony - Release Date: 2017-09-29
# 226 - Asterix & Obelix XXL 3 – The Crystal Menhir - Release Date: 2019-11-21
# 227 - Guns, Gore and Cannoli 2 - Release Date: 2018-08-09
# 228 - Scott Pilgrim vs. the World: The Game - Complete Edition - Release Date: 2021-01-14
# 229 - Watch Dogs Complete Edition - Release Date: 2015-08-26
# 230 - The Adventure Pals - Release Date: 2018-04-03
# 231 - Mutant Football League  - Release Date: 2019-04-18
# 232 - The Sims™ 4 Eco Lifestyle - Release Date: 2020-06-05
# 233 - Dreams - Release Date: 2020-02-14
# 234 - Bonds of the Skies - Release Date: 2019-06-26
# 235 - NARUTO TO BORUTO: SHINOBI STRIKER - Release Date: 2018-08-30
# 236 - Ashes Cricket - Release Date: 2017-11-16
# 237 - Ranch Planet - Release Date: 2018-06-15
# 238 - Splasher - Release Date: 2017-09-26
# 239 - MotoGP™18 - Release Date: 2018-06-07
# 240 - Sniper Elite V2 Remastered - Release Date: 2019-05-14
# 241 - Sackboy: A Big Adventure - Release Date: 2020-11-19
# 242 - Tacoma - Release Date: 2017-08-02
# 243 - Street Fighter V: Champion Edition - Release Date: 2020-02-14
# 244 - Earth Atlantis - Release Date: 2018-06-01
# 245 - HIVE: Altenum Wars - Release Date: 2018-05-01
# 246 - Where are my friends? - Release Date: 2018-03-21
# 247 - Beholder Complete Edition - Release Date: 2018-02-02
# 248 - Killing Floor: Incursion - Release Date: 2018-05-01
# 249 - ACA NEOGEO METAL SLUG 4 - Release Date: 2018-08-09
# 250 - Toto Temple Deluxe - Release Date: 2015-09-30
# 251 - Rocket Arena Mythic Edition - Release Date: 2020-07-14
# 252 - Oh...Sir! The Hollywood Roast! - Release Date: 2018-06-01
# 253 - Sakuna: Of Rice and Ruin - Release Date: 2020-11-12
# 254 - Ys: Memories of Celceta "Timeless Adventurer Edition" - Release Date: 2012-09-27
# 255 - Sparklite - Release Date: 2019-11-14
# 256 - PAW Patrol Mighty Pups Save Adventure Bay - Release Date: 2020-11-06
# 257 - The Path of Motus - Release Date: 2018-07-17
# 258 - My Universe - Cooking Star Restaurant - Release Date: 2020-11-10
# 259 - The Fisherman - Fishing Planet - Release Date: 2019-10-15
# 260 - Steven Universe: Save the Light - Release Date: 2017-12-19
# 261 - Salary Man Escape VR - Release Date: 2018-06-26
# 262 - NBA 2K18 - Release Date: 2017-09-15
# 263 - Ninjin: Clash of Carrots - Release Date: 2018-09-04
# 264 - For The King - Release Date: 2018-04-19
# 265 - EarthNight - Release Date: 2019-12-03
# 266 - My Time at Portia - Release Date: 2019-04-16
# 267 - S.O.N - Release Date: 2019-03-28
# 268 - ACA NEOGEO BASEBALL STARS 2 - Release Date: 2019-03-21
# 269 - The TakeOver - Release Date: 2021-05-20
# 270 - Destiny 2 - Release Date: 2017-09-06
# 271 - Game Tengoku CruisinMix Special - Release Date: 2020-05-28
# 272 - Radial-G: Racing Revolved - Release Date: 2016-12-31
# 273 - Sakura Wars - Release Date: 2020-05-12
# 274 - Brawlout - Release Date: 2018-08-21
# 275 - The Wardrobe - Release Date: 2018-07-31
# 276 - Samurai Shodown - Release Date: 1993-07-07
# 277 - NHL 20 - Release Date: 2019-09-13
# 278 - Outriders - Release Date: 2021-04-01
# 279 - The Crew 2 - Release Date: 2018-06-29
# 280 - Little Nightmares II - Release Date: 2021-02-11
# 281 - Cluster Tumble - Release Date: 2018-04-30
# 282 - Hammerwatch - Release Date: 2017-12-20
# 283 - Yu-Gi-Oh! Legacy of the Duelist: Link Evolution - Release Date: 2020-03-24
# 284 - Persian Nights: Sands of Wonders - Release Date: 2018-08-17
# 285 - Hotline Miami 2: Wrong Number  - Release Date: 2015-03-10
# 286 - ACA NEOGEO SAMURAI SHODOWN IV - Release Date: 2018-04-19
# 287 - Fortnite: Darkfire Bundle - Release Date: 2017-09-26
# 288 - Sea of Solitude - Release Date: 2019-07-05
# 289 - Hello Neighbor - Release Date: 2018-07-27
# 290 - AER - Memories of Old - Release Date: 2017-10-25
# 291 - Guts and Glory - Release Date: 2017-02-15
# 292 - Mitch: Berry Challenge - Release Date: 2017-12-31
# 293 - Pop-Up Pilgrims - Release Date: 2018-02-13
# 294 - Onimusha: Warlords - Release Date: 2019-01-15
# 295 - Illusion of L'Phalcia - Release Date: 2019-07-03
# 296 - Future Unfolding - Release Date: 2017-05-16
# 297 - SnowRunner - Release Date: 2020-04-28
# 298 - Songbird Symphony - Release Date: 2019-07-25
# 299 - Hover - Release Date: 2015-04-06
# 300 - Shadows: Awakening - Release Date: 2018-09-04
# 301 - Desperados III - Release Date: 2020-06-16
# 302 - AI: The Somnium Files - Release Date: 2021-09-30
# 303 - Honor and Duty: D-Day - Release Date: 2019-02-26
# 304 - SHINY - Release Date: 2016-08-31
# 305 - Island Flight Simulator - Release Date: 2015-04-17
# 306 - Golden Force - Release Date: 2021-05-27
# 307 - Jak & Daxter The Precursor Legacy - Release Date: 2012-02-29
# 308 - OF MICE AND SAND -REVISED- - Release Date: 2018-04-03
# 309 - Baldur's Gate Enhanced Edition - Release Date: 2019-10-15
# 310 - Bridge Constructor Portal - Release Date: 2018-03-01
# 311 - Squareboy vs Bullies: Arena Edition - Release Date: 2017-12-06
# 312 - The Walking Dead: Season Two - Release Date: 2013-12-18
# 313 - Agony - Release Date: 2018-05-29
# 314 - Apex Legends - Lifeline Edition - Release Date: 2019-12-03
# 315 - Duck Game - Release Date: 2017-08-22
# 316 - Conan Exiles - Release Date: 2018-05-08
# 317 - Harvest Moon: One World - Release Date: 2021-09-28
# 318 - Song Of Memories - Release Date: 2019-02-01
# 319 - F1 2018 - Release Date: 2018-08-24
# 320 - Castaway Paradise - Release Date: 2018-07-31
# 321 - RollerCoaster Tycoon Joyride - Release Date: 2018-12-13
# 322 - RIDE 3 - Release Date: 2018-11-30
# 323 - Organ Trail Complete Edition - Release Date: 2015-10-20
# 324 - NASCAR Heat 3 - Release Date: 2018-09-07
# 325 - Sakuna: Of Rice and Ruin "Divine Edition" - Release Date: 2020-11-10
# 326 - The Angry Birds Movie 2 VR: Under Pressure - Release Date: 2019-08-06
# 327 - 8-Bit Hordes - Release Date: 2019-02-01
# 328 - Scribblenauts Showdown - Release Date: 2018-03-09
# 329 - 18 Floors - Release Date: 2018-07-03
# 330 - Strange Brigade - Release Date: 2018-08-28
# 331 - Spike Volleyball - Release Date: 2019-02-05
# 332 - Hellblade: Senua's Sacrifice - Release Date: 2018-04-10
# 333 - Marenian Tavern Story: Patty and the Hungry God - Release Date: 2020-08-19
# 334 - Marvel's Spider-Man: Miles Morales - Release Date: 2020-11-12
# 335 - Let Them Come - Release Date: 2017-10-03
# 336 - Minecraft: Story Mode - Season Two - Episode 5: Above and Beyond - Release Date: 2017-12-19
# 337 - TOUHOU SKY ARENA MATSURI CLIMAX - Release Date: 2016-05-20
# 338 - AUDIOBEATS - Release Date: 2017-01-05
# 339 - The Walking Dead: The Final Season - Suffer The Children - Release Date: 2018-09-25
# 340 - What Remains of Edith Finch - Release Date: 2017-07-19
# 341 - Timespinner - Release Date: 2019-06-04
# 342 - Planescape Torment / Icewind Dale Enhanced Editions - Release Date: 2019-10-15
# 343 - Monstrum - Release Date: 2021-02-12
# 344 - Dungeons 3 - Release Date: 2017-10-12
# 345 - Stikbold! - Release Date: 2016-04-08
# 346 - Days Gone - Release Date: 2019-04-26
# 347 - Thimbleweed Park - Release Date: 2017-08-22
# 348 - 1979 Revolution: Black Friday - Release Date: 2018-08-03
# 349 - DRAGON BALL Z: KAKAROT - Release Date: 2020-01-17
# 350 - Destiny: Le Roi Des Corrompus - Release Date: 2017-02-23
# 351 - Dragooned - Release Date: 2011-07-06
# 352 - The Sims™ 4 Deluxe Party Pack - Release Date: 2014-09-02
# 353 - Defender's Quest: Valley of the Forgotten  - Release Date: 2012-01-20
# 354 - Always Sometimes Monsters - Release Date: 2014-05-20
# 355 - Generation Zero - Release Date: 2019-03-26
# 356 - HITMAN 3 - Release Date: 2021-01-20
# 357 - DEAD OR ALIVE 6 - Release Date: 2019-03-01
# 358 - The House in Fata Morgana - Release Date: 2019-06-11
# 359 - NBA Live 18 - Release Date: 2017-09-15
# 360 - Real Farm - Release Date: 2017-10-20
# 361 - Rival Megagun - Release Date: 2018-11-29
# 362 - Paranormal Activity: The Lost Soul - Release Date: 2017-08-15
# 363 - Expand - Release Date: 2017-10-03
# 364 - ACA NEOGEO AGGRESSORS OF DARK KOMBAT - Release Date: 2018-09-13
# 365 - HomeStarVR for PlayStationVR - Release Date: 2018-05-01
# 366 - Fallen Legion: Flames of Rebellion - Release Date: 2017-12-12
# 367 - Dragon Quest XI: Echoes of an Elusive Age  - Release Date: 2018-09-04
# 368 - Life is Strange 2: Episode 1 - Release Date: 2018-09-27
# 369 - Pix the Cat - Release Date: 2014-10-07
# 370 - Pillars of Eternity II Deadfire Ultimate Edition - Release Date: 2020-01-28
# 371 - Wolfenstein II: The New Colossus - Release Date: 2017-11-23
# 372 - Bomber Crew: Complete Edition - Release Date: 2017-10-19
# 373 - Red Faction - Release Date: 2017-08-28
# 374 - ACA NEOGEO BASEBALL STARS PROFESSIONAL - Release Date: 2018-05-17
# 375 - Sword & Fairy 6 - Release Date: 2019-04-02
# 376 - ATV Drift & Tricks - Release Date: 2017-11-14
# 377 - VA-11 HALL-A: Cyberpunk Bartender Action - Release Date: 2019-05-02
# 378 - void tRrLM(); //Void Terrarium - Release Date: 2020-07-14
# 379 - Siralim 3 - Release Date: 2019-03-29
# 380 - RollerCoaster Legends II: Thor's Hammer - Release Date: 2018-06-05
# 381 - Hyper Sentinel - Release Date: 2018-05-11
# 382 - Apex Legends - Octane Edition - Release Date: 2020-02-18
# 383 - Slice, Dice & Rice - Release Date: 2018-02-14
# 384 - EVEREST VR - Release Date: 2016-08-02
# 385 - Call of Duty®: Black Ops 4 - Release Date: 2010-11-09
# 386 - Costume Quest 2 - Release Date: 2014-10-29
# 387 - Truck Driver - Release Date: 2013-10-01
# 388 - PGA TOUR 2K21 - Release Date: 2020-08-21
# 389 - The Long Dark - Release Date: 2017-08-01
# 390 - Blaster Master Zero - Release Date: 2021-07-29
# 391 - NORTH - Release Date: 2016-04-27
# 392 - The Dark Pictures Anthology: Man of Medan - Release Date: 2019-08-30
# 393 - Remnant: From the Ashes - Release Date: 2019-08-20
# 394 - Accounting+ - Release Date: 2016-10-18
# 395 - Sky Force Reloaded - Release Date: 2017-11-28
# 396 - Power Rangers: Battle for the Grid - Release Date: 2019-04-02
# 397 - Hopalong: The Badlands - Release Date: 2017-04-03
# 398 - Hellmut - The Badass From Hell TM - Release Date: 2018-03-13
# 400 - 20XX - Release Date: 2018-07-10
# 401 - Walden, a game - Release Date: 2021-07-02
# 402 - The Raven Remastered - Release Date: 2018-03-13
# 403 - Concrete Genie - Release Date: 2019-10-09
# 404 - Midnight Deluxe - Release Date: 2018-10-24
# 405 - Darkest Dungeon - Release Date: 2018-10-11
# 406 - Nine Parchments - Release Date: 2018-03-07
# 407 - The Spectrum Retreat - Release Date: 2018-07-13
# 408 - MARS ODYSSEY - Release Date: 2019-12-10
# 409 - Omega Strike  - Release Date: 2018-06-15
# 410 - Stellaris: Console Edition - Release Date: 2019-02-26
# 411 - Stunt Kite Masters VR - Release Date: 2017-05-29
# 412 - The Jackbox Party Pack 4 - Release Date: 2017-10-17
# 413 - TerraTech - Release Date: 2018-08-14
# 414 - Dead Cells: Prisoner's Edition - Release Date: 2018-08-07
# 415 - Twin Robots - Release Date: 2017-10-10
# 416 - Street Power Football - Release Date: 2020-08-25
# 417 - Umihara Kawase Fresh! - Release Date: 2020-05-15
# 418 - The Sims™ 4 Snowy Escape - Release Date: 2020-11-13
# 419 - Scribblenauts Unlimited - Release Date: 2012-11-13
# 420 - Super Destronaut DX - Release Date: 2018-07-27
# 421 - Lost Sphear - Release Date: 2017-10-12
# 422 - Serious Sam Collection - Release Date: 2020-11-17
# 423 - All-Star Fruit Racing - Release Date: 2018-08-21
# 424 - Madden NFL 21 - Release Date: 2020-08-28
# 425 - Wulverblade - Release Date: 2018-01-31
# 426 - Space Pirate Trainer - Release Date: 2018-11-27
# 427 - Tales of Vesperia: Definitive Edition - Release Date: 2019-01-11
# 428 - NEW GUNDAM BREAKER - Release Date: 2018-06-21
# 429 - Battle Princess Madelyn - Release Date: 2019-01-07
# 430 - Sid Meier's Civilization VI - Release Date: 2019-11-22
# 431 - Ultrawings - Release Date: 2017-07-20
# 432 - Astérix & Obélix XXL 2 - Release Date: 1993-01-01
# 433 - NEKOPARA Vol.1 - Release Date: 2014-12-29
# 434 - Tricky Towers - Release Date: 2017-09-15
# 435 - ToeJam & Earl: Back in the Groove! - Release Date: 2019-03-01
# 436 - Boiling Bolt - Release Date: 2017-12-05
# 437 - Corpse Killer - Release Date: 1995-08-25
# 438 - Two Point Hospital - Release Date: 2020-02-25
# 439 - Tony Hawk's Pro Skater 1 and 2 - Release Date: 2021-03-26
# 440 - Marvel's Guardians of the Galaxy: The Telltale Series - Don't Stop Believin' - Release Date: 2017-11-07
# 441 - Catch & Release - Release Date: 2018-08-19
# 442 - Ghost 1.0 - Release Date: 2019-07-19
# 443 - Chaos on Deponia - Release Date: 2017-12-06
# 444 - DreamWorks Dragons Dawn of New Riders - Release Date: 2019-02-15
# 445 - Rad Rodgers - Release Date: 2018-02-21
# 446 - GALAK-Z: The Void - Release Date: 2017-02-23
# 447 - Word Search by POWGI - Release Date: 2018-08-07
# 448 - The Sims™ 4 Laundry Day Stuff - Release Date: 2018-08-14
# 449 - The Elder Scrolls Online: Greymoor - Release Date: 2020-06-09
# 450 - Surviving Mars - Release Date: 2018-03-15
# 451 - School Girl/Zombie Hunter - Release Date: 2017-11-17
# 452 - STAR WARS™ Episode I Racer - Release Date: 2020-10-27
# 453 - NIER REPLICANT VER.1.22474487139… - Release Date: 2021-04-22
# 454 - The Station - Release Date: 2017-07-31
# 455 - Hidden Dragon Legend - Release Date: 2017-09-19
# 456 - Air Missions: Hind - Release Date: 2018-09-25
# 457 - Zombie Army 4: Dead War - Release Date: 2020-02-04
# 458 - Dead by Daylight: Nightmare Edition - Release Date: 2019-12-06
# 459 - Blood & Truth - Release Date: 1997-03-07
# 460 - Marooners - Release Date: 2018-02-06
# 461 - Hunting Simulator 2 - Release Date: 2020-06-25
# 462 - Effie - Release Date: 2021-02-19
# 463 - Little Witch Academia: Chamber of Time - Release Date: 2018-05-15
# 464 - MXGP PRO - Release Date: 2018-07-10
# 465 - DWVR - Release Date: 2016-12-15
# 466 - Jettomero: Hero of the Universe - Release Date: 2018-02-27
# 467 - The aquatic Adventure of the Last Human - Release Date: 2018-01-23
# 468 - Pure Farming 2018 - Release Date: 2018-03-13
# 469 - Tetris Effect - Release Date: 2018-11-09
# 470 - Horizon Chase Turbo - Release Date: 2018-11-28
# 471 - TT Isle of Man - Release Date: 2020-03-19
# 472 - Mystik Belle  - Release Date: 2017-12-31
# 474 - Mega Man Zero/ZX Legacy Collection - Release Date: 2020-02-25
# 475 - Asdivine Kamura - Release Date: 2019-10-01
# 476 - Where the Water Tastes Like Wine - Release Date: 2019-11-29
# 477 - Let's Sing 2018 - Release Date: 2017-10-20
# 478 - Railway Empire - Release Date: 2018-01-30
# 479 - ACA NEOGEO FOOTBALL FRENZY - Release Date: 2018-08-30
# 480 - Under Night In-Birth Exe:Late[cl-r] - Release Date: 2020-02-21
# 481 - SUPER AMAZEBALLS - Release Date: 2017-05-16
# 482 - Rocketbirds: Hardboiled Chicken - Release Date: 2020-11-16
# 483 - DOOM Slayers Collection - Release Date: 2020-08-04
# 484 - Socketeer - Release Date: 2018-08-21
# 485 - My Little Riding Champion - Release Date: 2018-11-29
# 486 - Hellpoint - Release Date: 2020-07-30
# 487 - Demon's Tier+ - Release Date: 2020-06-09
# 488 - Starbound - Release Date: 2016-07-21
# 489 - Creed: Rise to Glory - Release Date: 2018-09-25
# 490 - Deadbolt - Release Date: 2016-03-13
# 491 - Goosebumps Dead of Night - Release Date: 2020-06-29
# 492 - H1Z1: Battle Royale - Release Date: 2018-08-07
# 493 - Dollhouse - Release Date: 2019-05-24
# 494 - Jak X: Combat Racing - Release Date: 2017-12-06
# 495 - Jurassic World Evolution - Release Date: 2019-12-16
# 496 - F1 2020 Deluxe Schumacher Edition - Release Date: 2020-07-10
# 497 - Downwell - Release Date: 2016-05-24
# 498 - New Super Lucky's Tale - Release Date: 2020-08-21
# 499 - KINGDOM HEARTS Melody of Memory - Release Date: 2020-11-13
# 500 - Detective Gallo - Release Date: 2018-08-15
# 501 - Zengeon - Release Date: 2019-01-18
# 502 - Little Red Lie - Release Date: 2018-01-09
# 503 - Yoku's Island Express - Release Date: 2018-05-29
# 504 - State of Mind - Release Date: 2018-08-15
# 505 - Dakar 18 - Release Date: 2018-09-28
# 506 - Dragon Fantasy: Volumes of Westeria - Release Date: 2019-05-21
# 507 - UnExplored - Release Date: 2018-09-30
# 508 - Infernium - Release Date: 2018-04-03
# 509 - Portal Of Evil - Release Date: 2021-03-05
# 510 - Atelier Ryza 2: Lost Legends & the Secret Fairy - Release Date: 2021-01-29
# 511 - Fossil Hunters - Release Date: 2018-06-28
# 512 - Arcade Archives THE NINJA WARRIORS - Release Date: 2017-09-07
# 513 - The Unknown City (Horror Begins Now.....Episode 1) - Release Date: 2018-07-03
# 514 - Bus Simulator 21 - Release Date: 2021-09-07
# 515 - Bus Simulator - Release Date: 2018-04-03
# 516 - Ni no Kuni II: REVENANT KINGDOM - Release Date: 2018-03-23
# 517 - Ninja Shodown - Release Date: 2017-10-06
# 518 - Void Bastards - Release Date: 2020-05-07
# 519 - Halloween Forever - Release Date: 2018-10-22
# 520 - Is It Wrong to Try to Pick Up Girls in a Dungeon? Infinite Combate - Release Date: 2020-08-07
# 521 - SNK HEROINES Tag Team Frenzy - Release Date: 2018-09-07
# 522 - Persona 5 Royal - Release Date: 2020-03-31
# 523 - Mutant Football League: Dynasty Edition - Release Date: 2018-10-30
# 524 - Knights of Pen and Paper +1 Deluxier Edition - Release Date: 2018-05-29
# 525 - Disintegration - Release Date: 2020-06-16
# 526 - Persona 5: Dancing in Starlight - Release Date: 2018-12-04
# 527 - Descenders - Release Date: 2019-05-07
# 528 - SENRAN KAGURA Peach Beach Splash - Release Date: 2017-09-26
# 529 - Neonwall - Release Date: 2018-09-13
# 530 - Bridge Constructor Portal  - Release Date: 2018-03-01
# 531 - The Awesome Adventures of Captain Spirit - Release Date: 2018-06-26
# 532 - Spirit Hunter: NG - Release Date: 2019-10-10
# 533 - 2064: Read Only Memories - Release Date: 2017-01-17
# 534 - Those Who Remain - Release Date: 2020-05-15
# 535 - Fort Defense - Release Date: 2013-11-27
# 536 - ROBOTICS;NOTES DaSH - Release Date: 2020-10-16
# 537 - OVERKILL'S The Walking Dead - Release Date: 2018-11-06
# 538 - CarX Drift Racing Online - Release Date: 2017-07-07
# 539 - Trials of Mana - Release Date: 2020-04-24
# 540 - Heroine Anthem Zero Episode 1 - Release Date: 2018-02-27
# 541 - Yakuza 3 - Release Date: 2009-02-26
# 542 - Tin and Kuna  - Release Date: 2020-09-10
# 543 - Tesla vs Lovecraft - Release Date: 2018-03-14
# 544 - The Night Journey - Release Date: 2018-06-26
# 545 - MotoGP20 - Release Date: 2014-06-20
# 546 - Need for Speed™ Payback - Release Date: 2017-11-10
# 547 - The Seven Deadly Sins  Knights of Britannia - Release Date: 2018-02-09
# 548 - Google Tilt Brush - Release Date: 2016-04-05
# 549 - Slide Stars - Release Date: 2020-11-10
# 550 - TOKI - Release Date: 1989-01-01
# 551 - MotoGP19 - Release Date: 2019-06-27
# 552 - Pro Evolution Soccer 2019 - Release Date: 2018-08-28
# 553 - Destiny Connect: Tick-Tock Travelers - Release Date: 2019-10-22
# 554 - The Walker - Release Date: 2012-02-16
# 555 - Mutant Year Zero: Road to Eden - Release Date: 2018-12-04
# 556 - The Sims™ 4 Bowling Night Stuff - Release Date: 2019-03-12
# 557 - Kill la Kill - IF - Release Date: 2019-07-26
# 558 - Apocalypse Rider - Release Date: 2018-08-23
# 559 - Deiland - Release Date: 2016-02-19
# 560 - Revolve - Release Date: 2017-10-10
# 561 - Capcom Beat 'em Up Bundle - Release Date: 2018-09-20
# 563 - Red Matter - Release Date: 2018-05-24
# 564 - Kingdom: New Lands - Release Date: 2016-08-09
# 565 - The Elder Scrolls Online: Elsweyr - Release Date: 2019-06-04
# 566 - Birdcakes - Release Date: 2018-05-29
# 567 - NBA Live 18: The ONE Edition - Release Date: 2017-09-15
# 568 - Strikers Edge - Release Date: 2018-01-30
# 569 - Perils of Baking - Release Date: 2018-08-16
# 570 - Labyrinth of Refrain: Coven of Dusk - Release Date: 2018-09-18
# 571 - Blaster Master Zero 2 - Release Date: 2019-03-20
# 572 - ACE OF SEAFOOD - Release Date: 2017-11-14
# 573 - Ghost Parade - Release Date: 2020-10-14
# 574 - Arcade Archives OMEGA FIGHTER - Release Date: 2018-07-26
# 575 - ACA NEOGEO SPIN MASTER - Release Date: 2017-09-14
# 576 - Dark Legion - Release Date: 2018-06-15
# 577 - Dream Match Tennis VR - Release Date: 2018-07-10
# 578 - The Lost Child - Release Date: 2018-06-29
# 579 - Bunny Must Die! Chelsea and the 7devils. - Release Date: 2012-10-02
# 580 - Super Hydorah - Release Date: 2017-12-13
# 581 - Floor Kids - Release Date: 2018-11-27
# 582 - DayZ - Release Date: 2019-05-29
# 583 - Aragami: Shadow Edition - Release Date: 2018-06-05
# 584 - The Sims™ 4 Fitness Stuff - Release Date: 2019-03-12
# 585 - NHL 94 Rewind - Release Date: 2021-11-04
# 586 - Warhammer: Vermintide 2 - Deluxe Edition - Release Date: 2018-03-08
# 587 - Persona 3: Dancing in Moonlight - Release Date: 2018-12-04
# 588 - Slay the Spire  - Release Date: 2019-05-21
# 589 - Monster Slayers  - Release Date: 2018-05-18
# 590 - 428: Shibuya Scramble - Release Date: 2018-09-21
# 591 - SPACE HULK - Release Date: 2013-08-15
# 592 - Unravel 2 - Release Date: 2018-06-09
# 593 - Layers of Fear : Masterpiece Edition  - Release Date: 2016-08-02
# 594 - LocoRoco 2 - Release Date: 2017-12-09
# 595 - State of Anarchy: Master of Mayhem - Release Date: 2018-08-01
# 596 - Yakuza 6: The Song of Life - Release Date: 2021-03-25
# 597 - Taxi Chaos - Release Date: 2021-02-23
# 598 - Shio - Release Date: 2017-05-04
# 599 - Metal Gear Survive - Release Date: 2018-02-22
# 600 - Neverending Nightmares - Release Date: 2016-05-03
# 601 - The Mummy Demastered - Release Date: 2017-10-24
# 602 - Frutakia 2 - Release Date: 2017-09-21
# 603 - Ark Park - Release Date: 2018-03-22
# 604 - Blue Angels Aerobatic Flight Simulator - Release Date: 2017-11-28
# 605 - Return of the Obra Dinn - Release Date: 2019-10-18
# 606 - Bud Spencer & Terence Hill - Slaps And Beans - Release Date: 2018-07-24
# 607 - Casey Powell Lacrosse 18 - Release Date: 2018-04-25
# 608 - MediEvil - Release Date: 1998-10-01
# 609 - THE INVISIBLE HOURS - Release Date: 2017-10-10
# 610 - The Evil Within 2 - Release Date: 2017-10-13
# 611 - PixelJunk Monsters 2 - Release Date: 2018-05-24
# 612 - Jak II - Release Date: 2012-02-29
# 613 - It's Quiz Time - Release Date: 2017-12-15
# 614 - Apex Legends - Bloodhound Edition - Release Date: 2019-12-03
# 615 - BRIKS 2 - Release Date: 2018-01-05
# 616 - SAMURAI SHODOWN NEOGEO COLLECTION - Release Date: 2020-07-28
# 617 - Sayonara Wild Hearts - Release Date: 2020-02-25
# 618 - Aces of the Luftwaffe - Squadron - Release Date: 2018-07-24
# 619 - Monster Jam Steel Titans 2 - Release Date: 2021-03-02
# 620 - COMMANDOS 2 & PRAETORIANS: HD REMASTER DOUBLE PACK - Release Date: 2020-01-23
# 621 - Cities: Skylines Parklife Edition - Release Date: 2018-05-24
# 622 - The Caligula Effect: Overdose - Release Date: 2019-03-22
# 623 - Ancestors Legacy - Release Date: 2019-08-13
# 624 - Super Mutant Alien Assault - Release Date: 2016-07-12
# 625 - ACA NEOGEO SAMURAI SHODOWN II - Release Date: 2017-09-21
# 626 - Claire: Extended Cut - Release Date: 2016-06-09
# 627 - ACA NEOGEO SAMURAI SHODOWN III - Release Date: 2018-02-01
# 628 - Okami HD - Release Date: 2012-11-01
# 629 - The Swords of Ditto - Release Date: 2018-04-24
# 630 - Timothy vs the Aliens - Release Date: 2021-12-03
# 631 - Arca's Path - Release Date: 2018-12-04
# 632 - AO Tennis 2 - Release Date: 2020-02-11
# 633 - Fast Striker - Release Date: 2018-10-17
# 634 - Terminator: Resistance - Release Date: 2019-11-15
# 635 - Watch Dogs Legion  - Release Date: 2020-10-29
# 636 - Serial Cleaner - Release Date: 2017-07-14
# 637 - Dust: An Elysian Tail - Release Date: 2012-08-15
# 638 - Rogue Legacy - Release Date: 2015-05-27
# 639 - Nex Machina - Release Date: 2017-06-20
# 640 - War Theatre - Release Date: 2020-04-23
# 641 - eFootball PES 2021 Season Update - Release Date: 2020-09-15
# 642 - Battlefield V - Release Date: 2019-09-25
# 643 - Rangi - Release Date: 2017-08-03
# 644 - My Memory of Us - Release Date: 2018-10-10
# 645 - Story of a Gladiator - Release Date: 2019-11-27
# 646 - Mecho Wars: Desert Ashes - Release Date: 2020-05-08
# 647 - Plants vs. Zombies Battle for Neighborville - Release Date: 2019-10-18
# 648 - Narcosis - Release Date: 2018-07-24
# 649 - Fishing Planet - Release Date: 2017-08-29
# 650 - The Sinking City - Release Date: 2019-06-27
# 651 - We Happy Few - Release Date: 2018-08-09
# 652 - Blacksad: Under the Skin - Release Date: 2019-11-05
# 653 - Tamashii - Release Date: 2019-12-17
# 654 - Kingdoms of Amalur: Re-Reckoning - Release Date: 2020-09-08
# 655 - Kero Blaster - Release Date: 2017-04-11
# 656 - Spirit of the North - Release Date: 2019-11-13
# 657 - Dynasty Feud - Release Date: 2017-12-14
# 658 - Maneater - Release Date: 2020-05-22
# 659 - Zanki Zero: Last Beginning - Release Date: 2019-04-10
# 660 - Spacejacked - Release Date: 2020-06-12
# 661 - HAJWALA - Release Date: 2018-06-26
# 662 - Atelier Ryza: Ever Darkness & the Secret Hideout - Release Date: 2019-11-01
# 663 - VirtuGO - Release Date: 2017-09-08
# 664 - DATE A LIVE: RIO-REINCARNATION - Release Date: 2018-10-01
# 665 - WRC 7 FIA World Rally Championship - Release Date: 2017-09-13
# 666 - SteamWorld Dig 2 - Release Date: 2018-11-21
# 667 - Illusion: A Tale of the Mind - Release Date: 2018-06-01
# 668 - Fortnite - The Last Laugh Bundle - Release Date: 2020-12-04
# 669 - Still Time - Release Date: 2017-08-29
# 670 - Monochrome Order - Release Date: 2019-11-05
# 671 - Hex Tunnel - Release Date: 2018-03-06
# 672 - Dynasty Warriors 9 Special Weapon Edition  - Release Date: 2018-02-08
# 673 - ACA NEOGEO GAROU: MARK OF THE WOLVES - Release Date: 2019-03-28
# 674 - The Sims™ 4 My First Pet Stuff Pack - Release Date: 2018-03-13
# 675 - Nightmare Boy - Release Date: 2017-10-25
# 676 - Fuser - Release Date: 2020-11-10
# 677 - The Wonderful 101: Remastered - Release Date: 2020-05-22
# 678 - Wreckfest - Release Date: 2019-08-27
# 679 - Extinction - Release Date: 2018-04-10
# 680 - Red Dead Online - Release Date: 2020-12-01
# 681 - Bladed Fury - Release Date: 2021-03-24
# 682 - Super Skull Smash GO! 2 Turbo - Release Date: 2018-07-17
# 683 - Surf World Series - Release Date: 2017-08-30
# 684 - Atelier Lydie and Suelle: The Alchemists and the Mysterious Paintings - Release Date: 2017-12-21
# 685 - Mahjong Carnival - Release Date: 2015-09-21
# 686 - Ancestors: The Humankind Odyssey - Release Date: 2019-12-06
# 687 - Mystik Belle - Release Date: 2017-12-31
# 688 - Contra Anniversary Collection - Release Date: 2019-06-11
# 689 - Project Highrise - Architect's Edition - Release Date: 2018-11-13
# 690 - INK - Release Date: 2015-08-05
# 691 - GAROU: MARK OF THE WOLVES™ - Release Date: 2015-02-15
# 692 - The Witch and the Hundred Knight 2 - Release Date: 2018-04-06
# 693 - SUPERHOT: MIND CONTROL DELETE - Release Date: 2020-07-16
# 694 - Guilt Battle Arena - Release Date: 2018-02-14
# 695 - WRC 9 FIA World Rally Championship - Release Date: 2020-09-04
# 696 - Gate Of Doom - Release Date: 2018-08-28
# 697 - BlazBlue: Cross Tag Battle - Release Date: 2018-06-22
# 698 - MXGP2019 - The Official Motocross Videogame - Release Date: 2016-04-07
# 699 - Detroit: Become Human - Release Date: 2018-05-25
# 700 - Growtopia  - Release Date: 2019-07-18
# 701 - Tharsis - Release Date: 2016-01-12
# 702 - Mahjong Gold - Release Date: 2018-03-14
# 703 - Destiny 2: Shadowkeep - Release Date: 2019-10-01
# 704 - Anodyne - Release Date: 2018-09-21
# 705 - Construction Simulator 2 Console Edition - Release Date: 2018-12-09
# 706 - Mad Rat Dead - Release Date: 2020-10-30
# 707 - The Survivalists - Release Date: 2020-10-09
# 708 - Just In Time Incorporated - Release Date: 2017-07-27
# 709 - Yaga - Release Date: 2019-11-12
# 710 - Caveman Warriors - Release Date: 2017-09-21
# 711 - NHL 18 - Release Date: 2017-09-15
# 712 - Reel Fishing: Road Trip Adventure - Release Date: 2019-09-17
# 713 - ACA NEOGEO KARNOV'S REVENGE - Release Date: 2017-11-15
# 714 - Symmetry - Release Date: 2018-03-06
# 715 - One Piece World Seeker - Release Date: 2019-03-15
# 716 - Tanuki Justice - Release Date: 2021-06-30
# 717 - Animal Super Squad - Release Date: 2019-02-01
# 718 - RICK AND MORTY: VIRTUAL RICK-ALITY - Release Date: 2017-04-20
# 719 - Disgaea 1 Complete - Release Date: 2018-07-26
# 720 - Monster Energy Supercross - The Official Videogame 4 - Release Date: 2021-03-08
# 721 - TERA - Release Date: 2018-04-03
# 722 - Risk of Rain 2 - Release Date: 2019-08-30
# 723 - Neptunia Virtual Stars - Release Date: 2021-03-02
# 724 - ACA NEOGEO THE KING OF FIGHTERS '98 - Release Date: 2017-01-11
# 725 - Remothered: Tormented Fathers - Release Date: 2018-07-25
# 726 - ACA NEOGEO STAKES WINNER - Release Date: 2018-05-02
# 727 - Konrad the Kitten - Release Date: 2018-02-23
# 728 - Speed Brawl - Release Date: 2018-09-18
# 729 - Maid of Sker - Release Date: 2020-07-28
# 730 - Tales from the Borderlands - Release Date: 2014-12-03
# 731 - Sekiro™: Shadows Die Twice - Release Date: 2019-03-22
# 732 - Grave Danger - Release Date: 2016-12-19
# 733 - Grim Fandango Remastered - Release Date: 2020-10-29
# 734 - Wasteland 3 - Release Date: 2020-08-28
# 735 - Borderlands Game of the Year - Release Date: 2019-04-03
# 736 - OK K.O.! Let's Play Heroes - Release Date: 2018-01-23
# 737 - NBA 2K21 - Release Date: 2020-09-04
# 738 - Fate/EXTELLA LINK - Release Date: 2019-03-22
# 739 - Los Sims™ 4 Star Wars™: Viaje a Batuu  - Release Date: 2020-09-08
# 740 - ToeJam and Earl: Back in the Groove - Release Date: 2019-03-01
# 741 - ACA NEOGEO SENGOKU 3 - Release Date: 2018-03-29
# 742 - Anamorphine - Release Date: 2018-07-31
# 743 - Shape of the World - Release Date: 2018-06-05
# 744 - WWE 2K20 - Release Date: 2019-10-22
# 745 - Astroneer - Release Date: 2019-11-15
# 746 - HEX: Card Clash - Release Date: 2016-01-26
# 747 - Mugsters - Release Date: 2018-07-17
# 748 - UFC 4 - Release Date: 2020-08-14
# 749 - Samurai Shodown V Special  - Release Date: 2017-09-12
# 750 - Ys VIII: Lacrimosa of Dana - Release Date: 2017-09-15
# 751 - Aggelos - Release Date: 2019-07-12
# 752 - Wonder Boy: The Dragon's Trap - Release Date: 2017-04-18
# 753 - Atari Flashback Classics Volume 3 - Release Date: 2018-12-13
# 754 - Gunducky Industries - Release Date: 2021-04-28
# 755 - Earth Defense Force 5 - Release Date: 2018-12-11
# 756 - Family Feud - Release Date: 1991-05-01
# 757 - Dead Age - Release Date: 2018-09-07
# 758 - Borderlands 3 - Release Date: 2019-09-13
# 759 - Metal Wolf Chaos XD - Release Date: 2019-08-06
# 760 - Five Nights at Freddy's: Core Collection - Release Date: 2021-01-12
# 761 - NBA LIVE 20 - Release Date: 2005-09-26
# 762 - Way of Redemption - Release Date: 2017-11-07
# 763 - Trine 4: The Nightmare Prince - Release Date: 2019-10-08
# 764 - Pixel Gear - Release Date: 2016-10-20
# 765 - R.B.I. Baseball 19 - Release Date: 2019-03-05
# 766 - Moving Out - Release Date: 2020-05-12
# 767 - Puyo Puyo Tetris 2 - Release Date: 2020-12-08
# 768 - The Walking Dead: The Final Season - Release Date: 2018-08-14
# 769 - Titan Quest - Release Date: 2006-06-26
# 770 - Drive On Moscow - Release Date: 2018-05-04
# 771 - Asdivine Hearts II - Release Date: 2019-01-15
# 772 - Dragon Quest XI S: Echoes of an Elusive Age - Definitive Edition - Release Date: 2020-12-04
# 773 - Dandara - Release Date: 2018-02-06
# 774 - Punch Line  - Release Date: 2018-10-09
# 775 - Bleed 2 - Release Date: 2018-02-09
# 776 - Yomawari: Midnight Shadows - Release Date: 2017-10-24
# 777 - Valfaris - Release Date: 2019-11-05
# 778 - Bugsnax - Release Date: 2020-11-12
# 779 - Nights of Azure 2: Bride of the New Moon - Release Date: 2017-10-24
# 780 - The Journey Down: Chapter Two - Release Date: 2014-08-25
# 781 - Journey Collector's Edition - Release Date: 2015-09-29
# 782 - The Sims™ 4 Jungle Adventure - Release Date: 2018-12-04
# 783 - FORGOTTON ANNE - Release Date: 2018-05-15
# 784 - Shovel Knight: Treasure Trove - Release Date: 2015-04-29
# 785 - My Friend Pedro  - Release Date: 2020-04-02
# 786 - NASCAR Heat 2 - Release Date: 2017-09-12
# 787 - WILL: A Wonderful World - Release Date: 2017-06-06
# 788 - DOOM Eternal - Release Date: 2020-03-20
# 789 - ACA NEOGEO SOCCER BRAWL - Release Date: 2017-11-22
# 791 - Professor  Rubik's Brain Fitness - Release Date: 2020-11-24
# 792 - Spectrum - Release Date: 2018-08-22
# 793 - Raw Data - Release Date: 2016-07-14
# 794 - INFERNO CLIMBER: REBORN - Release Date: 2019-03-28
# 795 - Tyr: Chains of Valhalla - Release Date: 2018-05-08
# 796 - Crisis on the Planet of the Apes - Release Date: 2018-04-02
# 797 - Timber Tennis Versus - Release Date: 2018-11-08
# 798 - YIIK: A Postmodern RPG - Release Date: 2019-01-17
# 799 - Megadimension Neptunia VIIR - Release Date: 2018-05-11
# 800 - Jumanji The Video Game - Release Date: 2019-11-08
# 801 - Splash Blast Panic - Release Date: 2019-10-24
# 802 - Apex Legends - Release Date: 2019-02-04
# 803 - Laws of Machine - Release Date: 2018-01-25
# 804 - Psyvariar Delta - Release Date: 2019-07-02
# 805 - Everspace: Stellar Edition - Release Date: 2017-05-25
# 806 - Gnomes Garden 2 - Release Date: 2018-11-14
# 807 - Chariot - Release Date: 2014-09-30
# 808 - Sea of Memories - Release Date: 2018-06-01
# 809 - Los Sims™ 4 - Release Date: 2014-09-02
# 810 - FIFA 21 - Release Date: 2020-10-06
# 811 - Hitman: Definitive Edition - Release Date: 2016-02-23
# 812 - 3D Billiards - Release Date: 2017-12-19
# 813 - The Exorcist: Legion VR - Release Date: 2018-06-19
# 814 - Moss - Release Date: 2018-02-27
# 815 - RIOT - Civil Unrest - Release Date: 2019-02-06
# 816 - Wraith - Release Date: 2017-10-15
# 817 - Spelunky - Release Date: 2012-07-04
# 818 - Get Over Here - Release Date: 2018-09-11
# 819 - Guns of Icarus Alliance - Release Date: 2018-05-01
# 820 - Don't Bite Me Bro! - Release Date: 2018-03-20
# 821 - Glass Masquerade - Release Date: 2019-02-08
# 822 - GUNGRAVE VR - Release Date: 2018-12-11
# 823 - Call of Duty®: Modern Warfare® - Release Date: 2007-11-05
# 824 - EA SPORTS™ FIFA 21 NXT LEVEL EDITION - Release Date: 2020-10-06
# 825 - The Sims™ 4 Movie Hangout Stuff - Release Date: 2019-02-19
# 826 - The Occupation - Release Date: 2019-03-05
# 827 - Sundered: Eldritch Edition - Release Date: 2018-12-21
# 828 - Resident Evil 2 - Release Date: 2019-01-25
# 829 - Impact Winter - Release Date: 2018-04-05
# 830 - Gnomes Garden 3: The thief of castles - Release Date: 2018-07-25
# 831 - RPG Maker MV - Release Date: 2020-09-11
# 832 - Trials Rising - Release Date: 2019-02-26
# 833 - Crash Bandicoot™ 4: It's About Time - Release Date: 2020-10-02
# 834 - Factotum 90 - Release Date: 2017-10-03
# 835 - Pankapu - Release Date: 2017-09-20
# 836 - Neverwinter Nights Enhanced Edition - Release Date: 2019-12-03
# 837 - Outward - Release Date: 2019-03-26
# 838 - Laser League - Release Date: 2018-05-10
# 839 - Ghost of Tsushima - Release Date: 2020-07-17
# 840 - Grim Legends 3: The Dark City - Release Date: 2018-05-10
# 841 - HackyZack - Release Date: 2019-02-13
# 842 - VROOM KABOOM - Release Date: 2018-08-14
# 843 - Dark Quest 2 - Release Date: 2019-04-17
# 844 - Celeste - Release Date: 2018-01-26
# 845 - The Walking Dead Onslaught - Release Date: 2020-09-29
# 846 - Gene Rain - Release Date: 2018-07-17
# 847 - PixelJunk VR™ Dead Hungry - Release Date: 2017-10-25
# 848 - Streets of Red : Devil's Dare Deluxe - Release Date: 2019-02-21
# 849 - The Sims™ 4 Spooky Stuff - Release Date: 2018-10-02
# 850 - Switchblade - Release Date: 1989-11-30
# 851 - Cloudpunk - Release Date: 2020-10-15
# 852 - FIFA 19 - Release Date: 2018-09-28
# 853 - Disaster Report 4: Summer Memories - Release Date: 2020-04-21
# 854 - Way of the Passive Fist - Release Date: 2018-03-06
# 855 - Alchemist's Castle - Release Date: 2018-03-27
# 856 - BATTLE GAREGGA REV.2016 - Release Date: 2016-12-12
# 857 - Wild Turkey Hunter - Release Date: 2018-01-24
# 858 - FIFA 20 - Release Date: 2019-09-27
# 859 - Mega Man 11 - Release Date: 2018-10-02
# 860 - Fill-a-Pix: Phil's Epic Adventure - Release Date: 2018-07-24
# 861 - Mortal Kombat 11 - Release Date: 2019-04-23
# 862 - RAID: WORLD WAR II - Release Date: 2017-10-13
# 863 - Heavy Fire: Red Shadow - Release Date: 2018-10-16
# 864 - Destiny - Release Date: 2014-09-09
# 865 - Electronauts - Release Date: 2018-08-07
# 866 - GOD EATER 3 - Release Date: 2019-02-08
# 867 - Torchlight II - Release Date: 2019-09-03
# 868 - Hotline Miami - Release Date: 2014-08-20
# 869 - Arcade Islands: Volume One - Release Date: 2018-09-07
# 870 - Mutazione - Release Date: 2021-05-26
# 871 - Catastronauts - Release Date: 2018-09-28
# 872 - Nightmares from the Deep 3: Davy Jones - Release Date: 2018-02-02
# 873 - Black Desert - Release Date: 2018-01-07
# 874 - No Man's Sky - Release Date: 2018-07-24
# 875 - IRON CRYPTICLE - Release Date: 2017-07-12
# 876 - Harvest Moon: Mad Dash - Release Date: 2020-08-21
# 877 - Chronos: Before the Ashes - Release Date: 2020-12-01
# 878 - Penn & Teller VR: F U, U, U, & U - Release Date: 2018-05-17
# 879 - Time Carnage - Release Date: 2017-05-15
# 880 - Planet Coaster Console Edition - Release Date: 2020-11-24
# 881 - Age of Wonders: Planetfall - Release Date: 2019-08-06
# 882 - Spacebase Startopia - Release Date: 2021-03-26
# 883 - Dragon Sinker: Descendants of Legend - Release Date: 2020-01-08
# 884 - Garfield Kart: Furious Racing - Release Date: 2019-11-07
# 885 - Assassin's Creed III Remastered  - Release Date: 2019-03-29
# ...
# 1133 - BoxVR - Release Date: 2017-06-13
# 1134 - The Elder Scrolls Online: Summerset - Release Date: 2018-06-05
# 1135 - Volgarr The Viking - Release Date: 2014-10-31
# 1136 - Black Desert Prestige Edition - Release Date: 2020-12-02
# 1137 - Attack on Titan 2 - Release Date: 2018-03-14
# 1138 - Children of Morta - Release Date: 2019-10-15
# 1139 - Ruined King: A League of Legends Story - Release Date: 2021-11-16
# 1140 - Fallout 76: Steel Dawn - Release Date: 2020-11-24
# 1141 - CAT Interstellar - Release Date: 2015-08-28
# 1142 - Tom Clancy's Rainbow Six Siege: Advanced Edition - Release Date: 2018-02-13
# 1143 - THE KING OF FIGHTERS™ COLLECTION: THE OROCHI SAGA - Release Date: 2008-12-08
# 1144 - Los Sims™ 4 Vida Isleña - Release Date: 2014-09-02
# 1145 - Azure Striker GUNVOLT: STRIKER PACK - Release Date: 2020-04-22
# 1146 - Dead Secret - Release Date: 2018-04-24
# 1147 - IKARUGA - Release Date: 2008-04-09
# 1148 - Killing Floor: Incursion  - Release Date: 2018-05-01
# 1149 - Pierhead Arcade - Release Date: 2016-09-21
# 1150 - Anima: Gate of Memories -The Nameless Chronicles - Release Date: 2018-06-19
# 1151 - Attack of the Earthlings - Release Date: 2019-03-05
# 1152 - My Universe : School teacher - Release Date: 2020-11-03
# 1153 - The Outer Worlds - Release Date: 2019-10-25
# 1154 - Life is Strange 2 Complete Season - Release Date: 2018-09-26
# 1155 - Bubsy: Paws On Fire! - Release Date: 2019-05-16
# 1156 - Castlevania Requiem: Symphony of the Night & Rondo of Blood - Release Date: 2018-10-26
# 1157 - Ruiner - Release Date: 2017-09-26
# 1158 - MLB The Show 18 - Release Date: 2018-03-27
# 1159 - My Universe - Pet Clinic Cats and Dogs - Release Date: 2021-02-09
# 1160 - Minecraft: Story Mode - Season Two - Episode 4: Below the Bedrock - Release Date: 2017-11-07
# 1161 - Wallachia: Reign of Dracula - Release Date: 2021-10-02
# 1162 - Floor Plan - Release Date: 2018-03-20
# 1163 - Wailing Heights - Release Date: 2018-08-15
# 1164 - Wattam - Release Date: 2019-12-17
# 1165 - ESPER - Release Date: 2018-06-29
# 1166 - FIVE NIGHTS AT FREDDY'S: HELP WANTED - Release Date: 2020-10-30
# 1167 - RICK AND MORTY: VIRTUAL RICK-ALITY  - Release Date: 2017-04-20
# 1168 - Just Dance 2020 - Release Date: 2019-11-05
# 1169 - Space Invaders Forever - Release Date: 2020-12-01
# 1170 - Steep: Winter Games Edition - Release Date: 2017-12-05
# 1171 - Rocket Arena - Release Date: 2020-07-14
# 1172 - Knights and Bikes - Release Date: 2020-11-05
# 1173 - Override: Mech City Brawl - Release Date: 2018-12-04
# 1174 - Crypt of the NecroDancer - Release Date: 2017-02-10
# 1175 - ACA NEOGEO Gururin - Release Date: 2018-04-12
# 1176 - Pool Nation - Release Date: 2019-07-09
# 1177 - PixARK - Release Date: 2019-05-31
# 1178 - Yakuza 5 - Release Date: 2015-12-08
# 1179 - LIGHTFIELD - Release Date: 2017-09-25
# 1180 - A Plague Tale : Innocence - Release Date: 2019-05-14
# 1181 - Chicken Assassin: Reloaded - Release Date: 2018-07-17
# 1182 - Hob - Release Date: 2017-09-26
# 1183 - Revenant Dogma - Release Date: 2018-09-12
# 1184 - The Sims™ 4 Star Wars™: Journey to Batuu - Release Date: 2020-09-08
# 1185 - Inertial Drift - Release Date: 2020-09-30
# 1186 - The Last of Us Part II - Release Date: 2020-06-19
# 1187 - Dragon Sinker - Release Date: 2020-01-08
# 1188 - Crayola Scoot - Release Date: 2018-10-23
# 1189 - The Lord of the Rings Living Card Game - Release Date: 2019-04-30
# 1190 - League of Evil - Release Date: 2018-09-19
# 1191 - Marvel's Spider-Man: Game of the Year Edition - Release Date: 2019-08-28
# 1192 - Island Time - Release Date: 2021-04-07
# 1193 - Red Dead Redemption 2 - Release Date: 2018-10-26
# 1194 - Pig Eat Ball - Release Date: 2019-10-18
# 1195 - CONTRA ROGUE CORPS - Release Date: 2019-09-24
# 1196 - The Walking Dead: Saints & Sinners - Complete Edition - Release Date: 2020-01-23
# 1197 - Mages of Mystralia - Release Date: 2017-08-22
# 1198 - Alone With You - Release Date: 2016-08-23
# 1199 - 8 To Glory - Release Date: 2018-07-31
# 1200 - Tokyo Xanadu eX+ - Release Date: 2017-12-08
# 1201 - FINAL FANTASY XV ROYAL EDITION - Release Date: 2018-03-06
# 1202 - Firefighters: Plant Fire Department - Release Date: 2017-11-30
# 1203 - Ghost of a Tale - Release Date: 2018-03-13
# 1204 - Achtung! Cthulhu Tactics - Release Date: 2018-11-21
# 1205 - Warhammer: Chaosbane - Release Date: 2019-05-31
# 1206 - MY HERO ONE'S JUSTICE 2 - Release Date: 2020-04-17
# 1207 - ONRUSH - Release Date: 2018-06-05
# 1208 - Fishing Sim World: Pro Tour Collector's Edition - Release Date: 2020-04-14
# 1209 - Windjammers - Release Date: 2017-08-29
# 1210 - ACA NEOGEO METAL SLUG X - Release Date: 2017-10-05
# 1211 - Utawarerumono: ZAN - Release Date: 2019-09-10
# 1212 - Destiny 2: New Light - Release Date: 2017-09-06
# 1213 - Star Wars Jedi Knight: Jedi Academy - Release Date: 2020-03-26
# 1214 - The Sims™ 4 Kids Room Stuff - Release Date: 2018-06-19
# 1215 - Outer Wilds - Release Date: 2019-10-15
# 1216 - FATAL FURY™ BATTLE ARCHIVES VOL.2 - Release Date: 2017-03-27
# 1217 - Raging Loop - Release Date: 2019-10-22
# 1218 - ACA NEOGEO THE KING OF FIGHTERS '99 - Release Date: 2018-04-05
# 1219 - Death's Gambit - Release Date: 2020-02-12
# 1220 - The Legend of Heroes: Trails of Cold Steel III - Release Date: 2019-10-29
# 1221 - Space Hulk: Deathwing - Enhanced Edition - Release Date: 2018-05-22
# 1222 - Damascus Gear: Operation Osaka  - Release Date: 2018-03-06
# 1223 - Real Heroes: Firefighter - Release Date: 2020-02-25
# 1224 - THE MIDNIGHT SANCTUARY - Release Date: 2018-10-04
# 1225 - Arcade Archives ARGUS - Release Date: 2018-08-30
# 1226 - Hand of the Gods: SMITE Tactics - Release Date: 2018-02-20
# 1227 - Hungry Shark World - Release Date: 2018-07-17
# 1228 - The Catch: Carp & Coarse - Release Date: 2020-06-30
# 1229 - Haimrik - Release Date: 2018-06-06
# 1230 - Immortal Realms: Vampire Wars - Release Date: 2020-08-28
# 1231 - Race with Ryan - Release Date: 2019-11-01
# 1232 - Shenmue I & II - Release Date: 2018-11-22
# 1233 - Disney Classic Games: Aladdin and The Lion King - Release Date: 2019-10-25
# 1234 - Mafia: Definitive Edition - Release Date: 2020-09-24
# 1235 - Banner Saga 3 - Release Date: 2018-07-26
# 1236 - Super Mega Baseball 2 - Release Date: 2018-05-01
# 1237 - Rogue Trooper Redux - Release Date: 2017-10-17
# 1238 - Beat Saber - Release Date: 2018-05-01
# 1239 - Blightbound - Release Date: 2021-07-27
# 1240 - LEGO Marvel Super Heroes 2 - Release Date: 2017-11-14
# 1241 - Shadows of Adam - Release Date: 2021-06-15
# 1242 - AeternoBlade II - Release Date: 2019-10-11
# 1243 - The Sims™ 4 Nifty Knitting - Release Date: 2020-07-28
# 1244 - Siralim - Release Date: 2015-04-24
# 1245 - ADK DAMASHII - Release Date: 2017-03-01
# 1246 - Ticket to Ride - Release Date: 2008-06-25
# 1247 - Madden NFL 20 - Release Date: 2019-08-02
# 1248 - Speed 3: Grand Prix - Release Date: 2020-11-06
# 1249 - Dungeon Rushers - Release Date: 2018-05-25
# 1250 - Assassin's Creed Odyssey  - Release Date: 2020-11-12
# 1251 - Wordhunters - Release Date: 2018-11-14
# 1252 - PAW Patrol: On A Roll! - Release Date: 2018-10-23
# 1253 - Monster Energy Supercross - The Official Videogame - Release Date: 2018-02-13
# 1254 - 13 Sentinels: Aegis Rim - Release Date: 2020-09-08
# 1255 - FINAL FANTASY XV POCKET EDITION HD - Release Date: 2018-09-06
# 1256 - TOKYO GHOUL:re CALL to EXIST - Release Date: 2019-11-15
# 1257 - Rain World  - Release Date: 2017-03-28
# 1258 - Project Nimbus: CODE MIRAI - Release Date: 2018-05-14
# 1259 - Sigi - A Fart for Melusina - Release Date: 2018-09-07
# 1260 - Yakuza 4 - Release Date: 2010-03-18
# 1261 - Castlevania Anniversary Collection - Release Date: 2019-05-16
# 1262 - Immortal: Unchained - Release Date: 2018-09-07
# 1263 - Defenders of Ekron - Definitive Edition - Release Date: 2018-08-07
# 1264 - Pro Fishing Simulator - Release Date: 2018-11-29
# 1265 - DOOM VFR - Release Date: 2017-12-01
# 1266 - Shift Quantum - Release Date: 2018-05-30
# 1267 - Burly Men at Sea - Release Date: 2017-09-19
# 1268 - Chicken Range - Release Date: 2018-06-29
# 1269 - VRog - Release Date: 2017-09-26
# 1270 - Bastion - Release Date: 2011-07-20
# 1271 - Just Deal With It! - Release Date: 2018-11-13
# 1272 - 36 Fragments of Midnight - Release Date: 2017-12-19
# 1273 - Dungreed - Release Date: 2020-10-27
# 1274 - DEAD OR ALIVE 6: Core Fighters - Release Date: 2019-03-01
# 1275 - ACA NEOGEO THE LAST BLADE 2 - Release Date: 2018-02-15
# 1276 - Biped - Release Date: 2020-09-18
# 1277 - ACA NEOGEO PREHISTORIC ISLE 2 - Release Date: 2018-08-02
# 1278 - Armello - Release Date: 2016-08-30
# 1279 - The Council - Episode 3 - Ripples  - Release Date: 2018-07-26
# 1280 - Life is Strange: Before the Storm Episode 1 - Release Date: 2017-08-31
# 1281 - ACA NEOGEO METAL SLUG 3 - Release Date: 2017-12-21
# 1282 - Knockout League - Release Date: 2018-03-08
# 1283 - Minefield - Release Date: 2018-03-21
# 1284 - The Sims™ 4 Toddler Stuff - Release Date: 2018-05-22
# 1285 - Call of Duty®: Modern Warfare 2 Campaign Remastered - Release Date: 2020-03-31
# 1286 - Ys: Memories of Celceta - Release Date: 2012-09-27
# 1287 - DCL - The Game - Release Date: 2020-02-19
# 1288 - Owlboy - Release Date: 2018-04-10
# 1289 - VRobot - Release Date: 2017-04-20
# 1290 - Hero Defense - Release Date: 2018-08-16
# 1291 - Flight of Light - Release Date: 2017-08-03
# 1292 - FINAL FANTASY IX - Release Date: 2019-02-13
# 1293 - GRID - Release Date: 2019-10-11
# 1294 - 8-bit Adventure Anthology: Volume I - Release Date: 2017-10-31
# 1295 - METAL SLUG XX - Release Date: 2018-05-29
# 1296 - Citadel: Forged with Fire - Release Date: 2019-11-01
# 1297 - Call of Duty: Warzone - Release Date: 2020-03-10
# 1298 - My Baby - Release Date: 2016-01-26
# 1299 - DOOM 64 - Release Date: 2020-03-20
# 1300 - JUMP FORCE - Release Date: 2019-02-15
# 1301 - Light Tracer - Release Date: 2017-09-26
# 1302 - Epic Dumpster Bear - Release Date: 2020-06-09
# 1303 - Let's Create! Pottery VR - Release Date: 2020-06-12
# 1304 - Destiny: The Taken King - Release Date: 2015-09-15
# 1305 - Haunted Dungeons "Hyakki Castle" - Release Date: 2018-08-30
# 1306 - LEGO The Incredibles - Release Date: 2018-07-13
# 1307 - Gunvolt Chronicles: Luminous Avenger iX - Release Date: 2019-09-26
# 1308 - God of War - Release Date: 2018-04-20
# 1309 - Hand of Fate 2 - Release Date: 2018-12-01
# 1310 - Assassin's Creed Origins  - Release Date: 2017-10-27
# 1311 - Maize - Release Date: 2017-09-12
# 1312 - Assassin's Creed Rogue Remastered - Release Date: 2018-03-20
# 1313 - Just Dance 2019 - Release Date: 2018-10-25
# 1314 - Invector - Release Date: 2019-12-10
# 1315 - CODE VEIN - Release Date: 2020-02-26
# 1316 - Untitled Goose Game - Release Date: 2019-12-17
# 1317 - DJMAX RESPECT - Release Date: 2018-03-06
# 1318 - Black Mirror - Release Date: 2017-11-28
# 1319 - NBA 2K20 - Release Date: 2019-09-06
# 1320 - Far Cry 3 Classic Edition - Release Date: 2018-06-26
# 1321 - Trollhunters Defenders of Arcadia - Release Date: 2020-09-25
# 1322 - Skelattack - Release Date: 2020-06-02
# 1323 - Jolt Family Robot Racer - Release Date: 2018-03-06
# 1325 - Super Pixel Racers  - Release Date: 2018-10-31
# 1326 - ACA NEOGEO SAMURAI SHODOWN V - Release Date: 2018-07-05
# 1327 - Blasphemous - Release Date: 2019-09-10
# 1328 - Pirate Flight (VR) - Release Date: 2018-04-30
# 1329 - Earthfall - Release Date: 2018-07-13
# 1330 - White Noise 2 - Release Date: 2017-09-01
# 1331 - GRIS - Release Date: 2019-11-26
# 1332 - Dead Land - Release Date: 2018-04-03
# 1333 - The Council - Release Date: 2018-03-13
# 1334 - CLANNAD - Release Date: 2015-11-23
# 1335 - Ben 10 - Release Date: 2012-11-30
# 1336 - Arcade Archives HEROIC EPISODE - Release Date: 2019-02-26
# 1337 - Subaeria - Release Date: 2018-04-24
# 1338 - The Legend of Heroes: Trails of Cold Steel  - Release Date: 2019-03-26
# 1339 - Knights of Valour - Release Date: 2017-11-16
# 1340 - TINY METAL - Release Date: 2017-12-21
# 1341 - Rage Room - Release Date: 2017-12-25
# 1342 - Under Night In-Birth Exe:Late[st]  - Release Date: 2018-02-09
# 1343 - Vegas Party - Release Date: 2018-09-28
# 1344 - Secret of Mana - Release Date: 2018-02-15
# 1345 - The End is Nigh - Release Date: 2019-04-29
# 1346 - Forgotton Anne - Release Date: 2018-05-15
# 1347 - Train Sim World®2 - Release Date: 2017-03-16
# 1348 - Treadnauts - Release Date: 2018-08-17
# 1349 - Seek Hearts - Release Date: 2019-12-03
# 1350 - Slayaway Camp - Release Date: 2017-10-23
# 1351 - WARHAMMER 40,000 : DEATHWATCH - Release Date: 2015-10-16
# 1352 - Another World - 20th Anniversary Edition - Release Date: 2014-07-08
# 1353 - SuperEpic: The Entertainment War - Release Date: 2019-12-12
# 1354 - Damascus Gear Operation Osaka HD Edition - Release Date: 2018-03-06
# 1355 - Pillars of Eternity II: Deadfire - Release Date: 2020-01-28
# 1356 - Spyro™ Reignited Trilogy - Release Date: 2018-11-13
# 1357 - Inception VR - Release Date: 2017-02-23
# 1358 - Ghostbusters: The Video Game Remastered - Release Date: 2019-10-04
# 1359 - The Pathless - Release Date: 2020-11-12
# 1360 - Bulb Boy - Release Date: 2017-10-06
# 1361 - Indivisible - Release Date: 2019-10-07
# 1362 - NHL 19 - Release Date: 2018-09-14
# 1363 - Is It Wrong to Try to Pick Up Girls in a Dungeon? Familia Myth Infinite Combate - Release Date: 2020-08-11
# 1364 - VR Karts - Release Date: 2015-04-17
# 1365 - The Rabbit Hole - Release Date: 2016-10-11
# 1366 - We Sing Pop - Release Date: 2017-10-24
# 1367 - Blasters of the Universe - Release Date: 2018-02-27
# 1368 - Apex Legends - Pathfinder Edition - Release Date: 2020-05-26
# 1369 - GAL*GUNVOLT BURST - Release Date: 2018-04-13
# 1370 - The Metronomicon: Slay the Dance Floor - Release Date: 2017-08-30
# 1371 - Abo Khashem - Release Date: 2018-02-23
# 1372 - Space Junkies  - Release Date: 2019-03-26
# 1373 - VR Ping Pong Pro - Release Date: 2019-11-12
# 1374 - South Park: The Stick of Truth - Release Date: 2018-02-13
# 1375 - Bibi & Tina at the Horse Farm - Release Date: 2019-10-10
# 1376 - Guacamelee! 2 - Release Date: 2019-01-18
# 1377 - Fishing Master - Release Date: 2007-09-18
# 1378 - Planet Alpha - Release Date: 2018-09-04
# 1379 - Home Sweet Home - Release Date: 2007-11-22
# 1380 - Steel Rats - Release Date: 2018-11-07
# 1381 - Baldur's Gate: Enhanced Edition / Baldur's Gate II: Enhanced Edition - Release Date: 2019-10-15
# 1382 - L.A. Noire - Release Date: 2011-07-07
# 1383 - Immortals Fenyx Rising - Release Date: 2020-12-03
# 1384 - Lumines Remastered - Release Date: 2018-06-26
# 1385 - DEADBOLT - Release Date: 2016-03-13
# 1386 - Utawarerumono: Prelude to the Fallen - Release Date: 2020-05-29
# 1387 - Dynasty Warriors 9 Special Scenario Edition - Release Date: 2018-02-08
# 1388 - The Inpatient - Release Date: 2017-11-21
# 1389 - Last Day of June - Release Date: 2017-08-31
# 1390 - No Heroes Here - Release Date: 2018-05-29
# 1391 - The Council - Episode 4 - Burning Bridges - Release Date: 2018-09-25
# 1392 - Mega Man X Legacy Collection 2 - Release Date: 2018-07-24
# 1393 - Decay of Logos - Release Date: 2019-08-30
# 1394 - Old Man's Journey - Release Date: 2019-03-04
# 1395 - Next Up Hero - Release Date: 2018-01-11
# 1396 - Seven: The Days Long Gone - Release Date: 2017-11-30
# 1397 - World of Warriors - Release Date: 2014-11-04
# 1398 - The Journey Down: Chapter One - Release Date: 2012-05-18
# 1399 - Daymare: 1998 Black Edition - Release Date: 2019-09-16
# 1400 - Overwatch Legendary Edition - Release Date: 2019-06-20
# 1401 - Borderlands 2 VR - Release Date: 2018-12-14
# 1402 - fault - milestone one - Release Date: 2020-05-22
# 1403 - Graveyard Keeper - Release Date: 2019-06-27
# 1404 - ACA NEOGEO REAL BOUT FATAL FURY 2 - Release Date: 2018-03-08
# 1405 - Rock Boshers DX: Director's Cut - Release Date: 2014-12-09
# 1406 - Cryptract - Release Date: 2018-09-25
# 1407 - Train Sim World - Release Date: 2018-07-24
# 1408 - A Hole New World - Release Date: 2017-09-05
# 1409 - Monkey King Hero is Back - Release Date: 2019-10-17
# 1410 - Aaero - Release Date: 2017-04-11
# 1411 - The Inner World - The Last Wind Monk - Release Date: 2017-10-24
# 1412 - Animal Force - Release Date: 2018-07-10
# 1413 - L.A. Noire: The VR Case Files - Release Date: 2017-12-15
# 1414 - Little Adventure on the Prairie - Release Date: 2018-02-21
# 1415 - Screencheat - Release Date: 2016-03-01
# 1416 - The Sims™ 4 Parenthood - Release Date: 2018-06-19
# 1417 - The Sims™ 4 Spa Day - Release Date: 2019-04-18
# 1418 - RAD - Release Date: 2019-08-20
# 1419 - INSIDE - Release Date: 2016-06-28
# 1420 - Smoke and Sacrifice - Release Date: 2019-01-15

# %%
data = {
    'title': arrTitles,
    'console': arrConsoles,
    'date': arrDates,
    'year': arrYears,
    'month': arrMonths,
    'day': arrDays
}
release_dates = pd.DataFrame(data)
release_dates
# Out:
#                                       title  console        date  year  month  \
# 0                                >Observer_        1  2017-08-15  2017      8
# 1     THE KING OF FIGHTERS '97 GLOBAL MATCH        0  2018-04-03  2018      4
# 2                          Far Cry New Dawn        1  2019-02-15  2019      2
# 3            Candle: The Power of the Flame        1  2018-07-25  2018      7
# 4                        Planet of the Eyes        1  2017-09-19  2017      9
# ...                                     ...      ...         ...   ...    ...
# 1416                 The Sims™ 4 Parenthood        1  2018-06-19  2018      6
# 1417                    The Sims™ 4 Spa Day        1  2019-04-18  2019      4
# 1418                                    RAD        1  2019-08-20  2019      8
# 1419                                 INSIDE        0  2016-06-28  2016      6
# 1420                    Smoke and Sacrifice        1  2019-01-15  2019      1
#
#       day
# 0      15
# 1       3
# 2      15
# 3      25
# 4      19
# ...   ...
# 1416   19
# 1417   18
# 1418   20
# 1419   28
# 1420   15
#
# [1421 rows x 6 columns]

# %%
# Save to a csv
release_dates.to_csv('data/release_dates.csv', index=False, header=True)

# %%
# Generate report about release dates
my_report = sv.analyze(release_dates)
my_report.show_html(filepath='analysis-reports/sv_release_dates_report.html', open_browser=False)

# %% [markdown]
# ## B. Generate Costs <a name = "genCosts"></a>
# - **Custos de Produção:** [Segundo análises](https://www.gamevicio.com/noticias/2021/09/shawn-layden-fala-sobre-os-custos-irrealistas-de-us-200-milhoes-na-producao-de-jogos-aaa-atualmente/), o desenvolvimento de um jogo para a PS4 e Xbox One da classe AAA ronda entre os 120Milhões e 160M de dólares. Assim, estamos a assumir que os custos de produção para todos os nossos jogos estão entre 105M€ e 145M€. Para além disto também generalizamos que dos custos totais de produção, 30% são utilizados para atividades relacionadas com o marketing do jogo e 70% estão alocados para o desenvolvimento do jogo em si.
#
# [Voltar ao Índice](#index)

# %%
games = pd.read_csv('data/train.csv')

#https://www.gamevicio.com/noticias/2021/09/shawn-layden-fala-sobre-os-custos-irrealistas-de-us-200-milhoes-na-producao-de-jogos-aaa-atualmente/
# Custo de producao em euros
data = np.random.randint(105000000, 145000000, size=len(games))
production_costs = pd.DataFrame(data, columns=['production_cost'])

# Marketing 30%
# Desenvolvimento do jogo 70%
marketing_costs = []
development_costs = []
new_marketing_costs = []
new_development_costs = []
for i in range(len(production_costs)):
    row = production_costs.loc[i,:]
    marketing_cost =  round(row['production_cost'] * 0.30)
    development_cost = round(row['production_cost'] * 0.70)
    marketing_costs.append(marketing_cost)
    development_costs.append(development_cost)

production_costs.insert(1, 'marketing_cost', marketing_costs)
production_costs.insert(1, 'development_cost', development_costs)
production_costs
# Out:
#       production_cost  development_cost  marketing_cost
# 0           114264140          79984898        34279242
# 1           128953353          90267347        38686006
# 2           107921432          75545002        32376430
# 3           140790485          98553340        42237146
# 4           122715549          85900884        36814665
# ...               ...               ...             ...
# 1416        121944278          85360995        36583283
# 1417        119436569          83605598        35830971
# 1418        106757160          74730012        32027148
# 1419        115702393          80991675        34710718
# 1420        118837510          83186257        35651253
#
# [1421 rows x 3 columns]

# %%
# Save to a csv
production_costs.to_csv('data/production_costs.csv', index=False, header=True)

# %% [markdown]
# # 2. Data Warehousing (Transformation and Loading) <a name = "dw"></a>
# **Durante a construção do modelo multidimensional foram definidas regras** de forma a permitir uma melhor leitura, organização e funcionamento do modelo:
# - Nomenclatura em inglês, no singular, em to lower case e com underscore em vez de espaços;
# - Prefixos de modo a identificar a função de especificas tabelas e atributos;
# - Atribuição de um número máximo de caracteres aos atributos que necessitam que seja definido um limite de caracteres, exceto às Natural Keys, tendo sido assim definida uma margem de 10 caracteres adicionais para todos estes atributos.
#
# ![Modelo Multidimensional](images/modelo_multidimensional.png)
#
# Ao visualizar o modelo é passível identificar algumas **peculiaridades que o diferem dos demais**, são estas:
# - **Utilização de counters** na tabela de factos de modo a contar as linhas sinalizadas dado que alguns programas de criação de dashboards não retornam ou é complicado realizar este cálculo;
# - A tabela dimensão dim_esrb_rating_scale possui **different roles** devido ao facto de esta se referir a multiplos propósitos na tabela de factos (esrb_rating e pred_esrb_rating);
# - A tabela dimensão dim_esrb_rating_scale possui uma **Slowly Changing Dimensions Type 3**, isto é, permite-nos atualizar a dimensão sem ser necessário dar drop dos dados antigos;
# - **Utilização de Natural Keys (NK)** sempre que possível, uma coluna ou conjunto de colunas já existentes no(s) datasets com significado de negócio o que permite ser usada como parâmetro de pesquisa facilitando a etapa de ETL, diminuindo o número de queries e consequentemente o tempo para o carregamento dos dados da tabela de factos.

# %% [markdown]
# **Tópicos A (Generate Database) e B (Generate Tables)**
# <br>Antes de realizar o carregamento, criamos uma célula de código dedicada ao drop e criação, sequencialmente, da schema do Data Warehouse dentro do serviço MySQL. Seguidamente, recorrendo ao MySQL Workbench 8.0 CE, numa nova célula, foram feitas as queries de criação das tabelas de facto e dimensão e, posteriormente, implementadas em código dentro de outra célula do nosso notebook. Assim, sempre que necessário, podemos com apenas um clique executar o notebook, reiniciando assim todo o processo de data warehousing, sem nos preocuparmos com duplicação de dados nas tabelas com Surrogate Keys ou erros de duplicação de dados nas tabelas com Natural Keys.

# %% [markdown]
# ## A. Generate Database <a name = "genDB"></a>
# [Voltar ao Índice](#index)

# %%
dbName = "games_datawarehouse"

con = mysql.connector.connect(
    host="127.0.0.1",
    port=3306,
    user="root",
    passwd="password"
)

mycursor = con.cursor()

mycursor.execute(f"DROP DATABASE IF EXISTS {dbName}")
mycursor.execute(f"CREATE DATABASE {dbName}")
mycursor.close()
con.close()

# %% [markdown]
# ## B. Generate Tables <a name = "genTables"></a>
# [Voltar ao Índice](#index)

# %%
con = mysql.connector.connect(
    host="127.0.0.1",
    port=3306,
    user="root",
    passwd="password",
    database=dbName
)

mycursor = con.cursor()

mycursor.execute('''
CREATE TABLE IF NOT EXISTS `dim_console` (
  `NK_console` int NOT NULL,
  `description` varchar(24) NOT NULL,
  PRIMARY KEY (`NK_console`)
);
''')

mycursor.execute('''
CREATE TABLE IF NOT EXISTS `dim_date` (
  `NK_date` varchar(8) NOT NULL,
  `year` int NOT NULL,
  `month` int NOT NULL,
  `day` int NOT NULL,
  PRIMARY KEY (`NK_date`)
);
''')

mycursor.execute('''
CREATE TABLE IF NOT EXISTS `dim_esrb_rating_scale` (
  `NK_esrb_rating_scale` varchar(2) NOT NULL,
  `description` varchar(25) NOT NULL,
  `previous_description` varchar(25) DEFAULT NULL,
  PRIMARY KEY (`NK_esrb_rating_scale`)
);
''')

mycursor.execute('''
CREATE TABLE IF NOT EXISTS `fact_game` (
  `SK_game` int NOT NULL AUTO_INCREMENT,
  `release_date` varchar(8) NOT NULL,
  `console` int NOT NULL,
  `esrb_rating` varchar(2) NOT NULL,
  `pred_esrb_rating` varchar(2) NOT NULL,
  `alcohol_reference` bit(1) NOT NULL,
  `animated_blood` bit(1) NOT NULL,
  `blood` bit(1) NOT NULL,
  `blood_and_gore` bit(1) NOT NULL,
  `cartoon_violence` bit(1) NOT NULL,
  `crude_humor` bit(1) NOT NULL,
  `drug_reference` bit(1) NOT NULL,
  `fantasy_violence` bit(1) NOT NULL,
  `intense_violence` bit(1) NOT NULL,
  `language` bit(1) NOT NULL,
  `lyrics` bit(1) NOT NULL,
  `mature_humor` bit(1) NOT NULL,
  `mild_blood` bit(1) NOT NULL,
  `mild_cartoon_violence` bit(1) NOT NULL,
  `mild_fantasy_violence` bit(1) NOT NULL,
  `mild_language` bit(1) NOT NULL,
  `mild_lyrics` bit(1) NOT NULL,
  `mild_suggestive_themes` bit(1) NOT NULL,
  `mild_violence` bit(1) NOT NULL,
  `no_descriptors` bit(1) NOT NULL,
  `nudity` bit(1) NOT NULL,
  `partial_nudity` bit(1) NOT NULL,
  `sexual_content` bit(1) NOT NULL,
  `sexual_themes` bit(1) NOT NULL,
  `simulated_gambling` bit(1) NOT NULL,
  `strong_language` bit(1) NOT NULL,
  `strong_sexual_content` bit(1) NOT NULL,
  `suggestive_themes` bit(1) NOT NULL,
  `use_of_alcohol` bit(1) NOT NULL,
  `use_of_drugs_and_alcohol` bit(1) NOT NULL,
  `violence` bit(1) NOT NULL,
  `title` varchar(89) NOT NULL,
  `production_cost` int unsigned NOT NULL,
  `marketing_cost` int unsigned NOT NULL,
  `development_cost` int unsigned NOT NULL,
  `new_production_cost` int NOT NULL,
  `new_marketing_cost` int NOT NULL,
  `new_development_cost` int NOT NULL,
  `right_pred_counter` int NOT NULL,
  `wrong_pred_counter` int NOT NULL,
  `game_counter` int NOT NULL,
  PRIMARY KEY (`SK_game`),
  KEY `FK4_pred_esrb_rating_idx` (`pred_esrb_rating`),
  KEY `FK3_esrb_rating_idx` (`esrb_rating`),
  KEY `FK2_console_idx` (`console`),
  KEY `FK1_release_date_idx` (`release_date`),
  CONSTRAINT `FK1_release_date` FOREIGN KEY (`release_date`) REFERENCES `dim_date` (`NK_date`),
  CONSTRAINT `FK2_console` FOREIGN KEY (`console`) REFERENCES `dim_console` (`NK_console`),
  CONSTRAINT `FK3_esrb_rating` FOREIGN KEY (`esrb_rating`) REFERENCES `dim_esrb_rating_scale` (`NK_esrb_rating_scale`),
  CONSTRAINT `FK4_pred_esrb_rating` FOREIGN KEY (`pred_esrb_rating`) REFERENCES `dim_esrb_rating_scale` (`NK_esrb_rating_scale`) ON DELETE RESTRICT ON UPDATE RESTRICT
);
''')

# %% [markdown]
# ## C. Populate Dimensions <a name = "popDims"></a>

# %% [markdown]
# ### i. dim_esrb_rating_scale <a name = "dim_esrb_rating_scale"></a>
# - A chave primária é uma Natural Key;
# - Possui different roles;
# - Possui uma Slowly Changing Dimension do tipo 3.
#
# [Voltar ao Índice](#index)

# %%
# Applying Slowly Changing Dimensions type 3 by using "ON DUPLICATE KEY UPDATE" statement in the query

data = {
    'NK_esrb_rating_scale': ["RP", "EC", "E", "ET", "T", "M", "A", "ZZ"],
    'description': ["Rating Pending", "Early Childhood", "Everyone", "Everyone 10+", "Teen", "Mature", "Adult", "Not Rated"],
}
dim_esrb_rating_scale = pd.DataFrame(data)

for i in range(len(dim_esrb_rating_scale)):
    row = dim_esrb_rating_scale.loc[i,:]
    query = f'''
    INSERT INTO dim_esrb_rating_scale (NK_esrb_rating_scale, description)
    VALUES("{row["NK_esrb_rating_scale"]}","{row["description"]}")
    ON DUPLICATE KEY UPDATE
    NK_esrb_rating_scale = "{row["NK_esrb_rating_scale"]}",
    previous_description = description,
    description = "{row["description"]}"
    '''
    mycursor.execute(query)
    
con.commit()

# %% [markdown]
# ### ii. dim_console <a name = "dim_console"></a>
# - A chave primária é uma Natural Key.
#
# [Voltar ao Índice](#index)

# %%
data = {
    'NK_console': [0, 1],
    'description': ["PS4", "PS4 & Xbox One"],
}
dim_console = pd.DataFrame(data)

for i in range(len(dim_console)):
    row = dim_console.loc[i,:]
    query = f'''
    INSERT INTO dim_console (NK_console, description)
    VALUES({row["NK_console"]},"{row["description"]}")
    '''
    mycursor.execute(query)
    
con.commit()

# %% [markdown]
# ### iii. dim_date <a name = "dim_date"></a>
# - A chave primária é uma Natural Key, sendo esta uma agregação do ano, mês e dia.
#
# [Voltar ao Índice](#index)

# %%
release_dates = pd.read_csv('data/release_dates.csv')
release_dates = release_dates.drop_duplicates(subset=['year', 'month', 'day'])
release_dates.reset_index(drop=True, inplace=True)

for i in range(len(release_dates)):
    row = release_dates.loc[i,:]
    NK_date = str(row["year"]).zfill(4) + str(row["month"]).zfill(2) + str(row["day"]).zfill(2)
    query = f'''
    INSERT INTO dim_date (NK_date, year, month, day)
    VALUES("{NK_date}","{row["year"]}", "{row["month"]}", "{row["day"]}")
    '''
    mycursor.execute(query)
    
con.commit()

# %% [markdown]
# ## D. Populate Fact Table <a name = "popFact"></a>

# %% [markdown]
# ### i. fact_game <a name = "fact_game"></a>
# **A tabela de factos fact_game representa os jogos**, cada linha possuí um jogo, como atributos possui o título, as características (valores booleanos que indicam se o jogo possui ou não determinada característica, por exemplo, blood), o custo de produção, a data de lançamento, a consola e a classificação ESRB. Ainda, para os dados de teste foram adicionados novos atributos prevenientes do cálculo de todos os indicadores de desempenho (KPIs), tais como, a predição do ESRB rating e o novo custo de produção. Já para os dados de treino, uma vez que não são target para o cálculo das KPIs, foram aplicadas novas transformações de modo ao seu valor não ficar a null.
# <br>
# <br>Antes de inserir os factos, **foram aplicadas algumas transformações**:
# - Junção dos dois novos datasets (release_dates.csv e production_costs.csv) ao dataset principal (train.csv);
# - Adição de três novas colunas para o cálculo das KPIs remetentes ao novo custo de produção [new_production_cost (total), new_marketing_cost e new_development_cost];
# - Adição da coluna de previsão (pred_esrb_rating) e dois counters para o cálculo das KPIs taxa de acerto e taxa de erro;
# - Uma vez apenas foram calculadas as KPIs para os jogos com data de lançamento igual ou superior a 2019, utilizamos o valor "-1" para os atributos numéricos a null e o valor "ZZZZxlen" (último valor da escala alfabética consoante o tamanho da string) para os atributos strings a null.
#
# [Voltar ao Índice](#index)

# %%
games = pd.read_csv('data/train.csv')
# Applying the same transformations in the data preparation phase but
# this time we aren't transforming the ESRB rating into a numeric scale
# because we want to save the original value as a NK (Natural Key)
# Rename column strong_janguage to strong_language
games.rename(columns={'strong_janguage': 'strong_language'}, inplace=True, errors='raise')
#
release_dates = pd.read_csv('data/release_dates.csv')
production_costs = pd.read_csv('data/production_costs.csv')

arrReleaseDates = []
arrReleaseYears = []
arrProductionCosts = []
arrMarketingCosts = []
arrDevelopmentCosts = []
arrNewProductionCosts = []
arrNewMarketingCosts = []
arrNewDevelopmentCosts = []

pred_year = 2019

for i in range(len(games)):
    row_rd = release_dates.loc[i,:]
    row_pc = production_costs.loc[i,:]
    release_date = str(row_rd["year"]).zfill(4) + str(row_rd["month"]).zfill(2) + str(row_rd["day"]).zfill(2)
    release_year = row_rd["year"]
    production_cost = row_pc['production_cost']
    marketing_cost = row_pc['marketing_cost']
    development_cost = row_pc['development_cost']
    arrReleaseDates.append(release_date)
    arrReleaseYears.append(release_year)
    arrProductionCosts.append(production_cost)
    arrMarketingCosts.append(marketing_cost)
    arrDevelopmentCosts.append(development_cost)
    new_production_cost = -1
    new_marketing_cost = -1
    new_development_cost = -1
    # Cálculo das KPIs
    # Redução de custos entre 20% e 24% porque a accuracy do modelo atingiu 87.54%
    if (release_year >= pred_year):
        new_production_cost = round(((production_cost * (1-0.20)) + (production_cost * (1-0.24))) / 2)
        new_marketing_cost =  round(((marketing_cost * (1-0.20)) + (marketing_cost * (1-0.24))) / 2)
        new_development_cost = round(((development_cost * (1-0.20)) + (development_cost * (1-0.24))) / 2)
    arrNewProductionCosts.append(new_production_cost)
    arrNewMarketingCosts.append(new_marketing_cost)
    arrNewDevelopmentCosts.append(new_development_cost)
    
games.insert(35, 'release_date', arrReleaseDates)
games.insert(35, 'release_year', arrReleaseYears)
games.insert(35, 'production_cost', arrProductionCosts)
games.insert(35, 'marketing_cost', arrMarketingCosts)
games.insert(35, 'development_cost', arrDevelopmentCosts)
games.insert(35, 'new_production_cost', arrNewProductionCosts)
games.insert(35, 'new_marketing_cost', arrNewMarketingCosts)
games.insert(35, 'new_development_cost', arrNewDevelopmentCosts)

# %%
# Save to a csv
games.to_csv('data/data_merged.csv', index=False, header=True)

# %%
model = joblib.load('models/MLP_Classifier.pkl')

for i in range(len(games)):
    game_counter = 1
    row = games.loc[i,:]
    title = row["title"].replace('"', "^")
    
    pred = 'ZZ'
    if row["release_year"] >= pred_year:
        newData = np.array([[row['no_descriptors'],row['strong_language'],row['blood_and_gore'],row['fantasy_violence'],
        row['blood'],row['mild_fantasy_violence'],row['strong_sexual_content'],row['sexual_themes'],row['intense_violence'],
        row['suggestive_themes'],row['violence'],row['simulated_gambling'],row['sexual_content'],row['language'],
        row['mild_blood'],row['mild_suggestive_themes'],row['crude_humor'],row['mild_violence'],row['mild_lyrics'],
        row['cartoon_violence'],row['alcohol_reference'],row['lyrics'],row['drug_reference'],row['use_of_alcohol'],
        row['partial_nudity'],row['nudity'],row['mild_cartoon_violence'],row['animated_blood']]])
        
        pred = model.predict(newData)[0];
        if pred == 0:
            pred = 'E'
        elif pred == 1:
            pred = 'ET'
        elif pred == 2:
            pred = 'T'
        elif pred == 3:
            pred = 'M'
    
    right_pred_counter = 0
    wrong_pred_counter = 0
    if pred == "ZZ":
        right_pred_counter = -1
        wrong_pred_counter = -1
    elif pred == row["esrb_rating"]:
        right_pred_counter = 1
    else:
        wrong_pred_counter = 1
    
    query = f'''
    INSERT INTO fact_game (release_date, console, esrb_rating, pred_esrb_rating, alcohol_reference, animated_blood, blood,
    blood_and_gore, cartoon_violence, crude_humor, drug_reference, fantasy_violence, intense_violence, language, lyrics,
    mature_humor, mild_blood, mild_cartoon_violence, mild_fantasy_violence, mild_language, mild_lyrics, mild_suggestive_themes,
    mild_violence, no_descriptors, nudity, partial_nudity, sexual_content, sexual_themes, simulated_gambling, strong_language,
    strong_sexual_content, suggestive_themes, use_of_alcohol, use_of_drugs_and_alcohol, violence, title, production_cost,
    marketing_cost, development_cost, new_production_cost, new_marketing_cost, new_development_cost, 
    right_pred_counter, wrong_pred_counter, game_counter)
    VALUES("{row["release_date"]}", "{row["console"]}", "{row["esrb_rating"]}", "{pred}", {row["alcohol_reference"]},
    {row["animated_blood"]}, {row["blood"]}, {row["blood_and_gore"]}, {row["cartoon_violence"]}, 
    {row["crude_humor"]}, {row["drug_reference"]}, {row["fantasy_violence"]}, {row["intense_violence"]},
    {row["language"]}, {row["lyrics"]}, {row["mature_humor"]}, {row["mild_blood"]}, {row["mild_cartoon_violence"]},
    {row["mild_fantasy_violence"]}, {row["mild_language"]}, {row["mild_lyrics"]}, {row["mild_suggestive_themes"]},
    {row["mild_violence"]}, {row["no_descriptors"]}, {row["nudity"]}, {row["partial_nudity"]}, {row["sexual_content"]},
    {row["sexual_themes"]}, {row["simulated_gambling"]}, {row["strong_language"]}, {row["strong_sexual_content"]},
    {row["suggestive_themes"]}, {row["use_of_alcohol"]}, {row["use_of_drugs_and_alcohol"]}, {row["violence"]},
    "{title}", {row["production_cost"]}, {row["marketing_cost"]}, {row["development_cost"]}, {row["new_production_cost"]},
    {row["new_marketing_cost"]}, {row["new_development_cost"]}, {right_pred_counter}, {wrong_pred_counter}, {game_counter})
    '''
    mycursor.execute(query)
    
con.commit()

# %% [markdown]
# ## E. Create Views <a name = "createViews"></a>

# %% [markdown]
# ### i. view_game_prediction <a name = "view_game_prediction"></a>
# - As vistas materializadas (views) servem para que no momento da construção das dashboards tenhamos que fazer menos instruções Select ao Data Warehouse. Uma view é uma tabela que possui todos os dados de várias tabelas, incluindo a de factos e as suas dimensões, necessários para a construção das dashboards. Desta forma, o carregamento das dashboards torna-se mais rápido e mais satisfatório para o utilizador.
#
# [Voltar ao Índice](#index)

# %%
mycursor.execute('''
CREATE TABLE IF NOT EXISTS view_game_prediction (
    SELECT FG.console, FG.esrb_rating, FG.pred_esrb_rating, FG.right_pred_counter, FG.wrong_pred_counter,
    STR_TO_DATE(CONCAT(DD.year,'-',DD.month,'-',DD.day), '%Y-%m-%d') AS release_date,
    DD.year, DD.month, FG.production_cost, FG.marketing_cost, FG.development_cost, FG.new_production_cost,
    FG.new_marketing_cost, FG.new_development_cost, FG.game_counter, DC.description AS console_description
    FROM fact_game FG, dim_console DC, dim_date DD
    WHERE FG.release_date = DD.NK_date AND FG.console = DC.NK_console AND DD.year >= 2019
    ORDER BY release_date
);''')
mycursor.execute('''
ALTER TABLE view_game_prediction
ADD COLUMN `rowId` INT NOT NULL AUTO_INCREMENT FIRST,
ADD PRIMARY KEY (`rowId`)
;''')
con.commit()

# %%
# Close MySQL server connection
mycursor.close()
con.close()

# %%
# If we don't want to extract the MLPClassifier Model, we can just simply get the pred of the entire dataset using this function
from sklearn.neural_network import MLPClassifier

# Load functions
def get_pred(games, year=2019):
    data = games[['no_descriptors', 'strong_language', 'blood_and_gore', 'fantasy_violence', 'blood',
                          'mild_fantasy_violence', 'strong_sexual_content', 'sexual_themes', 'intense_violence',
                          'suggestive_themes', 'violence', 'simulated_gambling', 'sexual_content', 'language',
                          'mild_blood', 'mild_suggestive_themes', 'crude_humor', 'mild_violence', 'mild_lyrics',
                          'cartoon_violence', 'alcohol_reference', 'lyrics', 'drug_reference', 'use_of_alcohol',
                          'partial_nudity', 'nudity', 'mild_cartoon_violence', 'animated_blood', 'esrb_rating', 'release_year']]
    mapp = {'E':0, 'ET':1, 'T':2, 'M':3}
    data['esrb_rating'] = data['esrb_rating'].map(mapp)
    train = data[data['release_year'] < year]
    test = data[data['release_year'] >= year]

    X_train, y_train = train.iloc[:,0:28], train.iloc[:,28]
    X_test, y_test = test.iloc[:,0:28], test.iloc[:,28]

    clf = MLPClassifier(random_state=0, max_iter=1000, activation='tanh', alpha=0.05, hidden_layer_sizes=(20,), learning_rate= 'adaptive', solver= 'adam')
    clf.fit(X_train, y_train);
    joblib.dump(clf,'model.pkl')
    pred = clf.predict(X_test)
    #print(f"MLP Accuracy: {clf.score(X_test,y_test)}")
    #
    df = pd.DataFrame(pred, columns=['pred_esrb_rating'], index=test.index)
    df['pred_esrb_rating'] = df['pred_esrb_rating'].astype(str)
    mapp = {'0':'E', '1':'ET', '2':'T', '3':'M'}
    df['pred_esrb_rating'] = df['pred_esrb_rating'].map(mapp)
    #
    df2 = pd.DataFrame("ZZ", columns=['sample'], index=train.index)
    df_pre = pd.concat([df, df2], ignore_index=False, axis=1)
    df_pre['pred_esrb_rating'] = df_pre['pred_esrb_rating'].fillna("ZZ")
    df_pre.drop('sample', axis=1, inplace=True) 
    return df_pre
